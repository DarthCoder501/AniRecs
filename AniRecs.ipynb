# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sentence_transformers import SentenceTransformer
from difflib import get_close_matches
from datetime import datetime

# %%
anime_list_df = pd.read_csv("/content/anime.csv")
anime_descriptions_df = pd.read_csv("/content/anime_with_synopsis.csv")

# %%
anime_list_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# 2                             トライガン     TV       26
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV       26
# 4                            冒険王ビィト     TV       52
#
#                           Aired    Premiered  ...  Score-10   Score-9  \
# 0   Apr 3, 1998 to Apr 24, 1999  Spring 1998  ...  229170.0  182126.0
# 1                   Sep 1, 2001      Unknown  ...   30043.0   49201.0
# 2   Apr 1, 1998 to Sep 30, 1998  Spring 1998  ...   50229.0   75651.0
# 3   Jul 2, 2002 to Dec 24, 2002  Summer 2002  ...    2182.0    4806.0
# 4  Sep 30, 2004 to Sep 29, 2005    Fall 2004  ...     312.0     529.0
#
#     Score-8  Score-7  Score-6 Score-5 Score-4  Score-3  Score-2  Score-1
# 0  131625.0  62330.0  20688.0  8904.0  3184.0   1357.0    741.0   1580.0
# 1   49505.0  22632.0   5805.0  1877.0   577.0    221.0    109.0    379.0
# 2   86142.0  49432.0  15376.0  5838.0  1965.0    664.0    316.0    533.0
# 3   10128.0  11618.0   5709.0  2920.0  1083.0    353.0    164.0    131.0
# 4    1242.0   1713.0   1068.0   634.0   265.0     83.0     50.0     27.0
#
# [5 rows x 35 columns]

# %%
anime_descriptions_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1              Action, Drama, Mystery, Sci-Fi, Space
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                            sypnopsis
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...

# %%
new_anime_list_df = anime_list_df.drop(anime_list_df.iloc[:, 16:36], axis=1)

# %%
new_anime_list_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# 2                             トライガン     TV       26
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV       26
# 4                            冒険王ビィト     TV       52
#
#                           Aired    Premiered  \
# 0   Apr 3, 1998 to Apr 24, 1999  Spring 1998
# 1                   Sep 1, 2001      Unknown
# 2   Apr 1, 1998 to Sep 30, 1998  Spring 1998
# 3   Jul 2, 2002 to Dec 24, 2002  Summer 2002
# 4  Sep 30, 2004 to Sep 29, 2005    Fall 2004
#
#                                            Producers  \
# 0                                      Bandai Visual
# 1                             Sunrise, Bandai Visual
# 2                               Victor Entertainment
# 3  TV Tokyo, Bandai Visual, Dentsu, Victor Entert...
# 4                                   TV Tokyo, Dentsu
#
#                               Licensors         Studios    Source  \
# 0      Funimation, Bandai Entertainment         Sunrise  Original
# 1           Sony Pictures Entertainment           Bones  Original
# 2  Funimation, Geneon Entertainment USA        Madhouse     Manga
# 3      Funimation, Bandai Entertainment         Sunrise  Original
# 4                               Unknown  Toei Animation     Manga
#
#           Duration                          Rating
# 0  24 min. per ep.  R - 17+ (violence & profanity)
# 1    1 hr. 55 min.  R - 17+ (violence & profanity)
# 2  24 min. per ep.       PG-13 - Teens 13 or older
# 3  25 min. per ep.       PG-13 - Teens 13 or older
# 4  23 min. per ep.                   PG - Children

# %%
columns_to_drop = ["English name", "Japanese name", "Premiered", "Licensors"]

# %%
anime_stats = new_anime_list_df.drop(columns=columns_to_drop, axis=1)

# %%
anime_stats.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres   Type Episodes  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     TV       26
# 3  Action, Mystery, Police, Supernatural, Drama, ...     TV       26
# 4          Adventure, Fantasy, Shounen, Supernatural     TV       52
#
#                           Aired  \
# 0   Apr 3, 1998 to Apr 24, 1999
# 1                   Sep 1, 2001
# 2   Apr 1, 1998 to Sep 30, 1998
# 3   Jul 2, 2002 to Dec 24, 2002
# 4  Sep 30, 2004 to Sep 29, 2005
#
#                                            Producers         Studios  \
# 0                                      Bandai Visual         Sunrise
# 1                             Sunrise, Bandai Visual           Bones
# 2                               Victor Entertainment        Madhouse
# 3  TV Tokyo, Bandai Visual, Dentsu, Victor Entert...         Sunrise
# 4                                   TV Tokyo, Dentsu  Toei Animation
#
#      Source         Duration                          Rating
# 0  Original  24 min. per ep.  R - 17+ (violence & profanity)
# 1  Original    1 hr. 55 min.  R - 17+ (violence & profanity)
# 2     Manga  24 min. per ep.       PG-13 - Teens 13 or older
# 3  Original  25 min. per ep.       PG-13 - Teens 13 or older
# 4     Manga  23 min. per ep.                   PG - Children

# %%
anime_stats.isna().sum()
# Out:
# MAL_ID       0
# Name         0
# Score        0
# Genres       0
# Type         0
# Episodes     0
# Aired        0
# Producers    0
# Studios      0
# Source       0
# Duration     0
# Rating       0
# dtype: int64

# %%
# Fill rows with "Unknown" in "Episodes" volumn to -1
anime_stats["Episodes"] = anime_stats["Episodes"].replace(["Unknown"], -1)

# %%
# Drop rows that contain "Unknown"
anime_stats_cleaned = anime_stats[~(anime_stats == 'Unknown').any(axis=1)]

# %%
anime_stats_cleaned.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres   Type Episodes  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     TV       26
# 3  Action, Mystery, Police, Supernatural, Drama, ...     TV       26
# 4          Adventure, Fantasy, Shounen, Supernatural     TV       52
#
#                           Aired  \
# 0   Apr 3, 1998 to Apr 24, 1999
# 1                   Sep 1, 2001
# 2   Apr 1, 1998 to Sep 30, 1998
# 3   Jul 2, 2002 to Dec 24, 2002
# 4  Sep 30, 2004 to Sep 29, 2005
#
#                                            Producers         Studios  \
# 0                                      Bandai Visual         Sunrise
# 1                             Sunrise, Bandai Visual           Bones
# 2                               Victor Entertainment        Madhouse
# 3  TV Tokyo, Bandai Visual, Dentsu, Victor Entert...         Sunrise
# 4                                   TV Tokyo, Dentsu  Toei Animation
#
#      Source         Duration                          Rating
# 0  Original  24 min. per ep.  R - 17+ (violence & profanity)
# 1  Original    1 hr. 55 min.  R - 17+ (violence & profanity)
# 2     Manga  24 min. per ep.       PG-13 - Teens 13 or older
# 3  Original  25 min. per ep.       PG-13 - Teens 13 or older
# 4     Manga  23 min. per ep.                   PG - Children

# %%
# Select only the 'sypnopsis' column from anime_descriptions_df, along with the 'MAL_ID' for merging
anime_descriptions_df_subset = anime_descriptions_df[['MAL_ID', 'sypnopsis']]

# Merge anime_stats_cleaned with the subset of anime_descriptions_df, keeping only 'sypnopsis' from anime_descriptions_df
anime_df = pd.merge(anime_stats_cleaned, anime_descriptions_df_subset, on='MAL_ID', how='left')

# %%
anime_df
# Out:
#       MAL_ID                                               Name Score  \
# 0          1                                       Cowboy Bebop  8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira  8.39
# 2          6                                             Trigun  8.24
# 3          7                                 Witch Hunter Robin  7.27
# 4          8                                     Bouken Ou Beet  6.98
# ...      ...                                                ...   ...
# 5254   44086                                           Prayer X  6.75
# 5255   44208                                      Yami Shibai 8  6.09
# 5256   44236  Senyoku no Sigrdrifa: Dai-909 Senjutsu Hime-ta...  5.87
# 5257   46118                       Wave!!: Surfing Yappe!! (TV)  6.05
# 5258   48456                                SK∞: Crazy Rock Jam  6.52
#
#                                                  Genres     Type Episodes  \
# 0       Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# 1                 Action, Drama, Mystery, Sci-Fi, Space    Movie        1
# 2     Action, Sci-Fi, Adventure, Comedy, Drama, Shounen       TV       26
# 3     Action, Mystery, Police, Supernatural, Drama, ...       TV       26
# 4             Adventure, Fantasy, Shounen, Supernatural       TV       52
# ...                                                 ...      ...      ...
# 5254                                    Music, Dementia    Music        1
# 5255                     Dementia, Horror, Supernatural       TV       -1
# 5256                                   Action, Military  Special        1
# 5257                              Slice of Life, Sports       TV       12
# 5258                                     Comedy, Sports  Special        1
#
#                              Aired  \
# 0      Apr 3, 1998 to Apr 24, 1999
# 1                      Sep 1, 2001
# 2      Apr 1, 1998 to Sep 30, 1998
# 3      Jul 2, 2002 to Dec 24, 2002
# 4     Sep 30, 2004 to Sep 29, 2005
# ...                            ...
# 5254                   Aug 6, 2018
# 5255             Jan 11, 2021 to ?
# 5256                  Nov 28, 2020
# 5257             Jan 12, 2021 to ?
# 5258                  Mar 14, 2021
#
#                                               Producers           Studios  \
# 0                                         Bandai Visual           Sunrise
# 1                                Sunrise, Bandai Visual             Bones
# 2                                  Victor Entertainment          Madhouse
# 3     TV Tokyo, Bandai Visual, Dentsu, Victor Entert...           Sunrise
# 4                                      TV Tokyo, Dentsu    Toei Animation
# ...                                                 ...               ...
# 5254                           Sony Music Entertainment        PERIMETRON
# 5255                                           TV Tokyo              ILCA
# 5256                                            Aniplex      A-1 Pictures
# 5257                                        Delfi Sound  Asahi Production
# 5258                      Aniplex, Movic, ABC Animation             Bones
#
#         Source         Duration                          Rating  \
# 0     Original  24 min. per ep.  R - 17+ (violence & profanity)
# 1     Original    1 hr. 55 min.  R - 17+ (violence & profanity)
# 2        Manga  24 min. per ep.       PG-13 - Teens 13 or older
# 3     Original  25 min. per ep.       PG-13 - Teens 13 or older
# 4        Manga  23 min. per ep.                   PG - Children
# ...        ...              ...                             ...
# 5254  Original           3 min.       PG-13 - Teens 13 or older
# 5255  Original           4 min.       PG-13 - Teens 13 or older
# 5256  Original          24 min.       PG-13 - Teens 13 or older
# 5257     Other  23 min. per ep.       PG-13 - Teens 13 or older
# 5258  Original          23 min.       PG-13 - Teens 13 or older
#
#                                               sypnopsis
# 0     In the year 2071, humanity has colonized sever...
# 1     other day, another bounty—such is the life of ...
# 2     Vash the Stampede is the man with a $$60,000,0...
# 3     ches are individuals with special powers like ...
# 4     It is the dark century and the people are suff...
# ...                                                 ...
# 5254  usic video directed and animated by Ryoji Yama...
# 5255                     Eighth season of Yami Shibai .
# 5256  cap of the first eight episodes of Senyoku no ...
# 5257  asaki Hinaoka, who grew up near the coast of O...
# 5258               cap of the first 9 episodes of SK∞ .
#
# [5259 rows x 13 columns]

# %%
# Check for duplicated data
display(anime_df.duplicated(subset=['Name']).sum())
# Out:
# np.int64(0)

# %%
"""Temporal Processing for Aired"""
# Split on "to" to get start and end dates
anime_df[['start_str', 'end_str']] = anime_df['Aired'].str.split(' to ', expand=True)

# Get start and end dates in datetime format and leaves invalid strings like " ", or "?" into NaT
anime_df['start_date'] = pd.to_datetime(anime_df['start_str'], errors='coerce')
anime_df['end_date'] = pd.to_datetime(anime_df['end_str'], errors='coerce')

# Turns NaT for single time events (movies, music, etc) into same date as start date

# Add a column for ongoing shows
anime_df['ongoing'] = anime_df['Aired'].str.contains('to \?')

# Fill end_date for rows that are not ongoing
anime_df.loc[anime_df['end_date'].isna() & ~anime_df['ongoing'], 'end_date'] = anime_df['start_date']
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\?'
# <>:12: SyntaxWarning: invalid escape sequence '\?'
# /tmp/ipython-input-418620117.py:12: SyntaxWarning: invalid escape sequence '\?'
#   anime_df['ongoing'] = anime_df['Aired'].str.contains('to \?')

# %%
anime_df
# Out:
#       MAL_ID                                               Name Score  \
# 0          1                                       Cowboy Bebop  8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira  8.39
# 2          6                                             Trigun  8.24
# 3          7                                 Witch Hunter Robin  7.27
# 4          8                                     Bouken Ou Beet  6.98
# ...      ...                                                ...   ...
# 5254   44086                                           Prayer X  6.75
# 5255   44208                                      Yami Shibai 8  6.09
# 5256   44236  Senyoku no Sigrdrifa: Dai-909 Senjutsu Hime-ta...  5.87
# 5257   46118                       Wave!!: Surfing Yappe!! (TV)  6.05
# 5258   48456                                SK∞: Crazy Rock Jam  6.52
#
#                                                  Genres     Type Episodes  \
# 0       Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# 1                 Action, Drama, Mystery, Sci-Fi, Space    Movie        1
# 2     Action, Sci-Fi, Adventure, Comedy, Drama, Shounen       TV       26
# 3     Action, Mystery, Police, Supernatural, Drama, ...       TV       26
# 4             Adventure, Fantasy, Shounen, Supernatural       TV       52
# ...                                                 ...      ...      ...
# 5254                                    Music, Dementia    Music        1
# 5255                     Dementia, Horror, Supernatural       TV       -1
# 5256                                   Action, Military  Special        1
# 5257                              Slice of Life, Sports       TV       12
# 5258                                     Comedy, Sports  Special        1
#
#                              Aired  \
# 0      Apr 3, 1998 to Apr 24, 1999
# 1                      Sep 1, 2001
# 2      Apr 1, 1998 to Sep 30, 1998
# 3      Jul 2, 2002 to Dec 24, 2002
# 4     Sep 30, 2004 to Sep 29, 2005
# ...                            ...
# 5254                   Aug 6, 2018
# 5255             Jan 11, 2021 to ?
# 5256                  Nov 28, 2020
# 5257             Jan 12, 2021 to ?
# 5258                  Mar 14, 2021
#
#                                               Producers           Studios  \
# 0                                         Bandai Visual           Sunrise
# 1                                Sunrise, Bandai Visual             Bones
# 2                                  Victor Entertainment          Madhouse
# 3     TV Tokyo, Bandai Visual, Dentsu, Victor Entert...           Sunrise
# 4                                      TV Tokyo, Dentsu    Toei Animation
# ...                                                 ...               ...
# 5254                           Sony Music Entertainment        PERIMETRON
# 5255                                           TV Tokyo              ILCA
# 5256                                            Aniplex      A-1 Pictures
# 5257                                        Delfi Sound  Asahi Production
# 5258                      Aniplex, Movic, ABC Animation             Bones
#
#         Source         Duration                          Rating  \
# 0     Original  24 min. per ep.  R - 17+ (violence & profanity)
# 1     Original    1 hr. 55 min.  R - 17+ (violence & profanity)
# 2        Manga  24 min. per ep.       PG-13 - Teens 13 or older
# 3     Original  25 min. per ep.       PG-13 - Teens 13 or older
# 4        Manga  23 min. per ep.                   PG - Children
# ...        ...              ...                             ...
# 5254  Original           3 min.       PG-13 - Teens 13 or older
# 5255  Original           4 min.       PG-13 - Teens 13 or older
# 5256  Original          24 min.       PG-13 - Teens 13 or older
# 5257     Other  23 min. per ep.       PG-13 - Teens 13 or older
# 5258  Original          23 min.       PG-13 - Teens 13 or older
#
#                                               sypnopsis     start_str  \
# 0     In the year 2071, humanity has colonized sever...   Apr 3, 1998
# 1     other day, another bounty—such is the life of ...   Sep 1, 2001
# 2     Vash the Stampede is the man with a $$60,000,0...   Apr 1, 1998
# 3     ches are individuals with special powers like ...   Jul 2, 2002
# 4     It is the dark century and the people are suff...  Sep 30, 2004
# ...                                                 ...           ...
# 5254  usic video directed and animated by Ryoji Yama...   Aug 6, 2018
# 5255                     Eighth season of Yami Shibai .  Jan 11, 2021
# 5256  cap of the first eight episodes of Senyoku no ...  Nov 28, 2020
# 5257  asaki Hinaoka, who grew up near the coast of O...  Jan 12, 2021
# 5258               cap of the first 9 episodes of SK∞ .  Mar 14, 2021
#
#            end_str start_date   end_date  ongoing
# 0     Apr 24, 1999 1998-04-03 1999-04-24    False
# 1             None 2001-09-01 2001-09-01    False
# 2     Sep 30, 1998 1998-04-01 1998-09-30    False
# 3     Dec 24, 2002 2002-07-02 2002-12-24    False
# 4     Sep 29, 2005 2004-09-30 2005-09-29    False
# ...            ...        ...        ...      ...
# 5254          None 2018-08-06 2018-08-06    False
# 5255             ? 2021-01-11        NaT     True
# 5256          None 2020-11-28 2020-11-28    False
# 5257             ? 2021-01-12        NaT     True
# 5258          None 2021-03-14 2021-03-14    False
#
# [5259 rows x 18 columns]

# %%
columns_to_drop = ["start_str", "end_str", "Aired"]

# %%
anime_df = anime_df.drop(columns=columns_to_drop, axis=1)

# %%
anime_metadata = anime_df

# %%
anime_metadata.to_csv("Anime Metadata", index=False)

# %%
anime_df
# Out:
#       MAL_ID                                               Name Score  \
# 0          1                                       Cowboy Bebop  8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira  8.39
# 2          6                                             Trigun  8.24
# 3          7                                 Witch Hunter Robin  7.27
# 4          8                                     Bouken Ou Beet  6.98
# ...      ...                                                ...   ...
# 5254   44086                                           Prayer X  6.75
# 5255   44208                                      Yami Shibai 8  6.09
# 5256   44236  Senyoku no Sigrdrifa: Dai-909 Senjutsu Hime-ta...  5.87
# 5257   46118                       Wave!!: Surfing Yappe!! (TV)  6.05
# 5258   48456                                SK∞: Crazy Rock Jam  6.52
#
#                                                  Genres     Type Episodes  \
# 0       Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# 1                 Action, Drama, Mystery, Sci-Fi, Space    Movie        1
# 2     Action, Sci-Fi, Adventure, Comedy, Drama, Shounen       TV       26
# 3     Action, Mystery, Police, Supernatural, Drama, ...       TV       26
# 4             Adventure, Fantasy, Shounen, Supernatural       TV       52
# ...                                                 ...      ...      ...
# 5254                                    Music, Dementia    Music        1
# 5255                     Dementia, Horror, Supernatural       TV       -1
# 5256                                   Action, Military  Special        1
# 5257                              Slice of Life, Sports       TV       12
# 5258                                     Comedy, Sports  Special        1
#
#                                               Producers           Studios  \
# 0                                         Bandai Visual           Sunrise
# 1                                Sunrise, Bandai Visual             Bones
# 2                                  Victor Entertainment          Madhouse
# 3     TV Tokyo, Bandai Visual, Dentsu, Victor Entert...           Sunrise
# 4                                      TV Tokyo, Dentsu    Toei Animation
# ...                                                 ...               ...
# 5254                           Sony Music Entertainment        PERIMETRON
# 5255                                           TV Tokyo              ILCA
# 5256                                            Aniplex      A-1 Pictures
# 5257                                        Delfi Sound  Asahi Production
# 5258                      Aniplex, Movic, ABC Animation             Bones
#
#         Source         Duration                          Rating  \
# 0     Original  24 min. per ep.  R - 17+ (violence & profanity)
# 1     Original    1 hr. 55 min.  R - 17+ (violence & profanity)
# 2        Manga  24 min. per ep.       PG-13 - Teens 13 or older
# 3     Original  25 min. per ep.       PG-13 - Teens 13 or older
# 4        Manga  23 min. per ep.                   PG - Children
# ...        ...              ...                             ...
# 5254  Original           3 min.       PG-13 - Teens 13 or older
# 5255  Original           4 min.       PG-13 - Teens 13 or older
# 5256  Original          24 min.       PG-13 - Teens 13 or older
# 5257     Other  23 min. per ep.       PG-13 - Teens 13 or older
# 5258  Original          23 min.       PG-13 - Teens 13 or older
#
#                                               sypnopsis start_date   end_date  \
# 0     In the year 2071, humanity has colonized sever... 1998-04-03 1999-04-24
# 1     other day, another bounty—such is the life of ... 2001-09-01 2001-09-01
# 2     Vash the Stampede is the man with a $$60,000,0... 1998-04-01 1998-09-30
# 3     ches are individuals with special powers like ... 2002-07-02 2002-12-24
# 4     It is the dark century and the people are suff... 2004-09-30 2005-09-29
# ...                                                 ...        ...        ...
# 5254  usic video directed and animated by Ryoji Yama... 2018-08-06 2018-08-06
# 5255                     Eighth season of Yami Shibai . 2021-01-11        NaT
# 5256  cap of the first eight episodes of Senyoku no ... 2020-11-28 2020-11-28
# 5257  asaki Hinaoka, who grew up near the coast of O... 2021-01-12        NaT
# 5258               cap of the first 9 episodes of SK∞ . 2021-03-14 2021-03-14
#
#       ongoing
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 5254    False
# 5255     True
# 5256    False
# 5257     True
# 5258    False
#
# [5259 rows x 15 columns]

# %%
anime_df['end_date'] = anime_df['end_date'].fillna(pd.to_datetime('today'))

# %%
anime_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres   Type Episodes  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie        1
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen     TV       26
# 3  Action, Mystery, Police, Supernatural, Drama, ...     TV       26
# 4          Adventure, Fantasy, Shounen, Supernatural     TV       52
#
#                                            Producers         Studios  \
# 0                                      Bandai Visual         Sunrise
# 1                             Sunrise, Bandai Visual           Bones
# 2                               Victor Entertainment        Madhouse
# 3  TV Tokyo, Bandai Visual, Dentsu, Victor Entert...         Sunrise
# 4                                   TV Tokyo, Dentsu  Toei Animation
#
#      Source         Duration                          Rating  \
# 0  Original  24 min. per ep.  R - 17+ (violence & profanity)
# 1  Original    1 hr. 55 min.  R - 17+ (violence & profanity)
# 2     Manga  24 min. per ep.       PG-13 - Teens 13 or older
# 3  Original  25 min. per ep.       PG-13 - Teens 13 or older
# 4     Manga  23 min. per ep.                   PG - Children
#
#                                            sypnopsis start_date   end_date  \
# 0  In the year 2071, humanity has colonized sever... 1998-04-03 1999-04-24
# 1  other day, another bounty—such is the life of ... 2001-09-01 2001-09-01
# 2  Vash the Stampede is the man with a $$60,000,0... 1998-04-01 1998-09-30
# 3  ches are individuals with special powers like ... 2002-07-02 2002-12-24
# 4  It is the dark century and the people are suff... 2004-09-30 2005-09-29
#
#    ongoing
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
def preprocess(text):
    if pd.isna(text): return ""
    text = re.sub(r'[^\w\s-]', ' ', text)  # keep words, spaces, hyphens
    return re.sub(r'\s+', ' ', text).strip().lower()

# %%
# Preprocess text in textual columns
def preprocess(text):
    if pd.isna(text):
      return ""
    text = re.sub(r'[^\w\s-]', ' ', text)  # keep words, spaces, hyphens
    return re.sub(r'\s+', ' ', text).strip().lower()

# %%
textual_columns = ["Genres", "Type", "Producers", "Studios", "Source", "Duration", "Rating", "sypnopsis"]

for text_col in textual_columns:
  anime_df[text_col] = anime_df[text_col].apply(preprocess)

# %%
anime_df
# Out:
#       MAL_ID                                               Name Score  \
# 0          1                                       Cowboy Bebop  8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira  8.39
# 2          6                                             Trigun  8.24
# 3          7                                 Witch Hunter Robin  7.27
# 4          8                                     Bouken Ou Beet  6.98
# ...      ...                                                ...   ...
# 5254   44086                                           Prayer X  6.75
# 5255   44208                                      Yami Shibai 8  6.09
# 5256   44236  Senyoku no Sigrdrifa: Dai-909 Senjutsu Hime-ta...  5.87
# 5257   46118                       Wave!!: Surfing Yappe!! (TV)  6.05
# 5258   48456                                SK∞: Crazy Rock Jam  6.52
#
#                                               Genres     Type Episodes  \
# 0         action adventure comedy drama sci-fi space       tv       26
# 1                  action drama mystery sci-fi space    movie        1
# 2       action sci-fi adventure comedy drama shounen       tv       26
# 3     action mystery police supernatural drama magic       tv       26
# 4             adventure fantasy shounen supernatural       tv       52
# ...                                              ...      ...      ...
# 5254                                  music dementia    music        1
# 5255                    dementia horror supernatural       tv       -1
# 5256                                 action military  special        1
# 5257                            slice of life sports       tv       12
# 5258                                   comedy sports  special        1
#
#                                               Producers           Studios  \
# 0                                         bandai visual           sunrise
# 1                                 sunrise bandai visual             bones
# 2                                  victor entertainment          madhouse
# 3     tv tokyo bandai visual dentsu victor entertain...           sunrise
# 4                                       tv tokyo dentsu    toei animation
# ...                                                 ...               ...
# 5254                           sony music entertainment        perimetron
# 5255                                           tv tokyo              ilca
# 5256                                            aniplex      a-1 pictures
# 5257                                        delfi sound  asahi production
# 5258                        aniplex movic abc animation             bones
#
#         Source       Duration                     Rating  \
# 0     original  24 min per ep  r - 17 violence profanity
# 1     original    1 hr 55 min  r - 17 violence profanity
# 2        manga  24 min per ep  pg-13 - teens 13 or older
# 3     original  25 min per ep  pg-13 - teens 13 or older
# 4        manga  23 min per ep              pg - children
# ...        ...            ...                        ...
# 5254  original          3 min  pg-13 - teens 13 or older
# 5255  original          4 min  pg-13 - teens 13 or older
# 5256  original         24 min  pg-13 - teens 13 or older
# 5257     other  23 min per ep  pg-13 - teens 13 or older
# 5258  original         23 min  pg-13 - teens 13 or older
#
#                                               sypnopsis start_date  \
# 0     in the year 2071 humanity has colonized severa... 1998-04-03
# 1     other day another bounty such is the life of t... 2001-09-01
# 2     vash the stampede is the man with a 60 000 000... 1998-04-01
# 3     ches are individuals with special powers like ... 2002-07-02
# 4     it is the dark century and the people are suff... 2004-09-30
# ...                                                 ...        ...
# 5254  usic video directed and animated by ryoji yama... 2018-08-06
# 5255                       eighth season of yami shibai 2021-01-11
# 5256  cap of the first eight episodes of senyoku no ... 2020-11-28
# 5257  asaki hinaoka who grew up near the coast of oo... 2021-01-12
# 5258                  cap of the first 9 episodes of sk 2021-03-14
#
#                        end_date  ongoing
# 0    1999-04-24 00:00:00.000000    False
# 1    2001-09-01 00:00:00.000000    False
# 2    1998-09-30 00:00:00.000000    False
# 3    2002-12-24 00:00:00.000000    False
# 4    2005-09-29 00:00:00.000000    False
# ...                         ...      ...
# 5254 2018-08-06 00:00:00.000000    False
# 5255 2025-08-28 01:26:17.587144     True
# 5256 2020-11-28 00:00:00.000000    False
# 5257 2025-08-28 01:26:17.587144     True
# 5258 2021-03-14 00:00:00.000000    False
#
# [5259 rows x 15 columns]

# %%
"""One Hot Encoding for Type & Source"""
# Identify categorical columns to encode
one_hot_columns = ["Type", "Source"]

# Create a OneHotEncoder instance
encoder = OneHotEncoder(sparse_output=False)

# Fit and transform the selected categorical columns
one_hot_encoded_data = encoder.fit_transform(anime_df[one_hot_columns])

# Create a Dataframe from the encoded data
one_hot_df = pd.DataFrame(one_hot_encoded_data, columns=encoder.get_feature_names_out(one_hot_columns))


one_hot_encoded_df = pd.concat([anime_df.drop(columns=one_hot_columns), one_hot_df], axis=1)

# %%
"""TF-IDF for Genres, Rating, Producers, Studios"""
tfidf_columns = ["Genres", "Producers", "Studios", "Rating"]
tfidf_column_vectorizers = {}
tfidf_column_matrices = {}
tfidf_dfs = []

for tfidf_column in tfidf_columns:
    # Ensure the column contains strings & not lists
    text_series = one_hot_encoded_df[tfidf_column].astype(str)

    # Handle any NaN values
    text_series = text_series.fillna('')

    vectorizer = TfidfVectorizer()
    matrix = vectorizer.fit_transform(text_series)
    tfidf_column_vectorizers[tfidf_column] = vectorizer
    tfidf_column_matrices[tfidf_column] = matrix

    # Create DataFrame with proper column names
    feature_names = [f"{tfidf_column}_{feature}" for feature in vectorizer.get_feature_names_out()]
    tfidf_df = pd.DataFrame(matrix.toarray(), columns=feature_names, index=one_hot_encoded_df.index)
    tfidf_dfs.append(tfidf_df)

# Concatenate all TF-IDF features with original DataFrame
tfidf_combined_df = pd.concat([one_hot_encoded_df] + tfidf_dfs, axis=1)

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# Encode the synopsis into embeddings
synopsis_embeddings = model.encode(
    tfidf_combined_df["sypnopsis"].tolist(),
    convert_to_numpy=True
)

# create dataframe for embeddings
synposis_embeddings_df = pd.DataFrame(synopsis_embeddings, columns=[f"emb_{i}" for i in range(synopsis_embeddings.shape[1])])

# Combine with TF-IDF dataframe
text_vectorized_df = pd.concat([tfidf_combined_df.reset_index(drop=True), synposis_embeddings_df], axis=1)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
text_vectorized_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                            Genres Episodes  \
# 0      action adventure comedy drama sci-fi space       26
# 1               action drama mystery sci-fi space        1
# 2    action sci-fi adventure comedy drama shounen       26
# 3  action mystery police supernatural drama magic       26
# 4          adventure fantasy shounen supernatural       52
#
#                                            Producers         Studios  \
# 0                                      bandai visual         sunrise
# 1                              sunrise bandai visual           bones
# 2                               victor entertainment        madhouse
# 3  tv tokyo bandai visual dentsu victor entertain...         sunrise
# 4                                    tv tokyo dentsu  toei animation
#
#         Duration                     Rating  \
# 0  24 min per ep  r - 17 violence profanity
# 1    1 hr 55 min  r - 17 violence profanity
# 2  24 min per ep  pg-13 - teens 13 or older
# 3  25 min per ep  pg-13 - teens 13 or older
# 4  23 min per ep              pg - children
#
#                                            sypnopsis  ...   emb_374   emb_375  \
# 0  in the year 2071 humanity has colonized severa...  ...  0.041378 -0.008807
# 1  other day another bounty such is the life of t...  ...  0.073409 -0.031580
# 2  vash the stampede is the man with a 60 000 000...  ...  0.023642 -0.000594
# 3  ches are individuals with special powers like ...  ... -0.047775  0.064541
# 4  it is the dark century and the people are suff...  ... -0.033185 -0.002945
#
#     emb_376   emb_377   emb_378   emb_379   emb_380   emb_381   emb_382  \
# 0 -0.051468  0.120270 -0.005928 -0.009226  0.028198 -0.043460 -0.016529
# 1  0.000875  0.026888 -0.017871  0.012852  0.039618 -0.157760 -0.005686
# 2 -0.080299 -0.000698 -0.032473 -0.009470  0.029656 -0.087012  0.050944
# 3  0.046725 -0.029462 -0.025879 -0.040388  0.018040 -0.053823  0.057935
# 4 -0.058816  0.033064 -0.045447  0.008317  0.054319 -0.091631  0.057574
#
#     emb_383
# 0 -0.058174
# 1  0.008987
# 2 -0.024974
# 3 -0.021244
# 4  0.011912
#
# [5 rows x 2220 columns]

# %%
def extract_minutes(duration):
    match = re.search(r'(\d+)\s*min', duration)
    return int(match.group(1)) if match else 0
anime_df['Duration'] = anime_df['Duration'].apply(extract_minutes)

numeric_cols = ['Episodes','Score','Duration']
scaler = StandardScaler()
numeric_matrix = scaler.fit_transform(anime_df[numeric_cols])

# %%
numeric_df = pd.DataFrame(numeric_matrix, columns=scaler.get_feature_names_out(numeric_cols))

final_df = pd.concat([anime_df, text_vectorized_df], axis=1)

# %%
final_df
# Out:
#       MAL_ID                                               Name Score  \
# 0          1                                       Cowboy Bebop  8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira  8.39
# 2          6                                             Trigun  8.24
# 3          7                                 Witch Hunter Robin  7.27
# 4          8                                     Bouken Ou Beet  6.98
# ...      ...                                                ...   ...
# 5254   44086                                           Prayer X  6.75
# 5255   44208                                      Yami Shibai 8  6.09
# 5256   44236  Senyoku no Sigrdrifa: Dai-909 Senjutsu Hime-ta...  5.87
# 5257   46118                       Wave!!: Surfing Yappe!! (TV)  6.05
# 5258   48456                                SK∞: Crazy Rock Jam  6.52
#
#                                               Genres     Type Episodes  \
# 0         action adventure comedy drama sci-fi space       tv       26
# 1                  action drama mystery sci-fi space    movie        1
# 2       action sci-fi adventure comedy drama shounen       tv       26
# 3     action mystery police supernatural drama magic       tv       26
# 4             adventure fantasy shounen supernatural       tv       52
# ...                                              ...      ...      ...
# 5254                                  music dementia    music        1
# 5255                    dementia horror supernatural       tv       -1
# 5256                                 action military  special        1
# 5257                            slice of life sports       tv       12
# 5258                                   comedy sports  special        1
#
#                                               Producers           Studios  \
# 0                                         bandai visual           sunrise
# 1                                 sunrise bandai visual             bones
# 2                                  victor entertainment          madhouse
# 3     tv tokyo bandai visual dentsu victor entertain...           sunrise
# 4                                       tv tokyo dentsu    toei animation
# ...                                                 ...               ...
# 5254                           sony music entertainment        perimetron
# 5255                                           tv tokyo              ilca
# 5256                                            aniplex      a-1 pictures
# 5257                                        delfi sound  asahi production
# 5258                        aniplex movic abc animation             bones
#
#         Source  Duration  ...   emb_374   emb_375   emb_376   emb_377  \
# 0     original        24  ...  0.041378 -0.008807 -0.051468  0.120270
# 1     original        55  ...  0.073409 -0.031580  0.000875  0.026888
# 2        manga        24  ...  0.023642 -0.000594 -0.080299 -0.000698
# 3     original        25  ... -0.047775  0.064541  0.046725 -0.029462
# 4        manga        23  ... -0.033185 -0.002945 -0.058816  0.033064
# ...        ...       ...  ...       ...       ...       ...       ...
# 5254  original         3  ...  0.090700  0.107044  0.018753  0.032493
# 5255  original         4  ... -0.038754  0.044209 -0.009307 -0.062289
# 5256  original        24  ... -0.019292  0.031462 -0.017796  0.056616
# 5257     other        23  ...  0.011168 -0.010487 -0.063942  0.010269
# 5258  original        23  ...  0.047236  0.063548  0.056134 -0.027546
#
#        emb_378   emb_379   emb_380   emb_381   emb_382   emb_383
# 0    -0.005928 -0.009226  0.028198 -0.043460 -0.016529 -0.058174
# 1    -0.017871  0.012852  0.039618 -0.157760 -0.005686  0.008987
# 2    -0.032473 -0.009470  0.029656 -0.087012  0.050944 -0.024974
# 3    -0.025879 -0.040388  0.018040 -0.053823  0.057935 -0.021244
# 4    -0.045447  0.008317  0.054319 -0.091631  0.057574  0.011912
# ...        ...       ...       ...       ...       ...       ...
# 5254 -0.080742 -0.051087  0.026453  0.029584  0.029692 -0.042751
# 5255 -0.030723  0.008113  0.105199  0.028377 -0.034312  0.024800
# 5256 -0.062369 -0.038634  0.092818 -0.008020 -0.033852 -0.005082
# 5257 -0.042241  0.042111  0.104969  0.026636 -0.065326  0.028177
# 5258 -0.077629 -0.005455  0.038982 -0.015756 -0.089458  0.045026
#
# [5259 rows x 2235 columns]

# %%
anime_metadata
# Out:
#       MAL_ID                                               Name Score  \
# 0          1                                       Cowboy Bebop  8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira  8.39
# 2          6                                             Trigun  8.24
# 3          7                                 Witch Hunter Robin  7.27
# 4          8                                     Bouken Ou Beet  6.98
# ...      ...                                                ...   ...
# 5254   44086                                           Prayer X  6.75
# 5255   44208                                      Yami Shibai 8  6.09
# 5256   44236  Senyoku no Sigrdrifa: Dai-909 Senjutsu Hime-ta...  5.87
# 5257   46118                       Wave!!: Surfing Yappe!! (TV)  6.05
# 5258   48456                                SK∞: Crazy Rock Jam  6.52
#
#                                               Genres     Type Episodes  \
# 0         action adventure comedy drama sci-fi space       tv       26
# 1                  action drama mystery sci-fi space    movie        1
# 2       action sci-fi adventure comedy drama shounen       tv       26
# 3     action mystery police supernatural drama magic       tv       26
# 4             adventure fantasy shounen supernatural       tv       52
# ...                                              ...      ...      ...
# 5254                                  music dementia    music        1
# 5255                    dementia horror supernatural       tv       -1
# 5256                                 action military  special        1
# 5257                            slice of life sports       tv       12
# 5258                                   comedy sports  special        1
#
#                                               Producers           Studios  \
# 0                                         bandai visual           sunrise
# 1                                 sunrise bandai visual             bones
# 2                                  victor entertainment          madhouse
# 3     tv tokyo bandai visual dentsu victor entertain...           sunrise
# 4                                       tv tokyo dentsu    toei animation
# ...                                                 ...               ...
# 5254                           sony music entertainment        perimetron
# 5255                                           tv tokyo              ilca
# 5256                                            aniplex      a-1 pictures
# 5257                                        delfi sound  asahi production
# 5258                        aniplex movic abc animation             bones
#
#         Source  Duration                     Rating  \
# 0     original        24  r - 17 violence profanity
# 1     original        55  r - 17 violence profanity
# 2        manga        24  pg-13 - teens 13 or older
# 3     original        25  pg-13 - teens 13 or older
# 4        manga        23              pg - children
# ...        ...       ...                        ...
# 5254  original         3  pg-13 - teens 13 or older
# 5255  original         4  pg-13 - teens 13 or older
# 5256  original        24  pg-13 - teens 13 or older
# 5257     other        23  pg-13 - teens 13 or older
# 5258  original        23  pg-13 - teens 13 or older
#
#                                               sypnopsis start_date  \
# 0     in the year 2071 humanity has colonized severa... 1998-04-03
# 1     other day another bounty such is the life of t... 2001-09-01
# 2     vash the stampede is the man with a 60 000 000... 1998-04-01
# 3     ches are individuals with special powers like ... 2002-07-02
# 4     it is the dark century and the people are suff... 2004-09-30
# ...                                                 ...        ...
# 5254  usic video directed and animated by ryoji yama... 2018-08-06
# 5255                       eighth season of yami shibai 2021-01-11
# 5256  cap of the first eight episodes of senyoku no ... 2020-11-28
# 5257  asaki hinaoka who grew up near the coast of oo... 2021-01-12
# 5258                  cap of the first 9 episodes of sk 2021-03-14
#
#                        end_date  ongoing
# 0    1999-04-24 00:00:00.000000    False
# 1    2001-09-01 00:00:00.000000    False
# 2    1998-09-30 00:00:00.000000    False
# 3    2002-12-24 00:00:00.000000    False
# 4    2005-09-29 00:00:00.000000    False
# ...                         ...      ...
# 5254 2018-08-06 00:00:00.000000    False
# 5255 2025-08-28 01:26:17.587144     True
# 5256 2020-11-28 00:00:00.000000    False
# 5257 2025-08-28 01:26:17.587144     True
# 5258 2021-03-14 00:00:00.000000    False
#
# [5259 rows x 15 columns]

# %%
def diagnose_duplicate_columns(df, df_name="DataFrame"):
    """
    Diagnose and identify duplicate columns in a DataFrame
    """
    print(f"DUPLICATE COLUMN ANALYSIS FOR {df_name}")
    print("="*60)

    # Check for duplicate column names
    duplicate_cols = df.columns[df.columns.duplicated()].tolist()

    if duplicate_cols:
        print(f"DUPLICATE COLUMNS FOUND: {len(duplicate_cols)}")
        print(f"Duplicate column names: {duplicate_cols}")

        # Show details for each duplicate
        for col_name in set(duplicate_cols):
            indices = [i for i, x in enumerate(df.columns) if x == col_name]
            print(f"\nColumn '{col_name}' appears at positions: {indices}")

            if len(indices) > 1:
                try:
                    # Check if the duplicate columns have identical data
                    first_col = df.iloc[:, indices[0]]
                    identical = True
                    for i in range(1, len(indices)): # Iterate through indices list
                        idx = indices[i] # Get the actual index from the list
                        if idx < df.shape[1]:  # Safety check
                            other_col = df.iloc[:, idx]
                            if not first_col.equals(other_col):
                                identical = False
                                break

                    print(f"  Data identical across duplicates: {identical}")

                    # Show sample data from each duplicate
                    for i, idx in enumerate(indices):
                        if idx < df.shape[1]:  # Safety check
                            sample_data = df.iloc[:3, idx].tolist()
                            print(f"  Position {idx} sample: {sample_data}")
                except Exception as e:
                    print(f"  Error comparing duplicates: {e}")
                    print(f"  Skipping detailed analysis for '{col_name}'")
    else:
        print("NO DUPLICATE COLUMNS FOUND")

    return duplicate_cols

def fix_duplicate_columns(df, strategy='keep_first'):
    """
    Fix duplicate columns in DataFrame

    Parameters:
    - strategy: 'keep_first', 'keep_last', or 'suffix'
    """
    print(f"\n FIXING DUPLICATE COLUMNS (strategy: {strategy})")

    original_shape = df.shape

    if strategy == 'keep_first':
        # Keep only the first occurrence of each column name
        df_fixed = df.loc[:, ~df.columns.duplicated()]

    elif strategy == 'keep_last':
        # Keep only the last occurrence of each column name
        df_fixed = df.loc[:, ~df.columns.duplicated(keep='last')]

    elif strategy == 'suffix':
        # Add suffixes to make column names unique
        df_fixed = df.copy()

        # Get duplicate column names
        duplicate_mask = df_fixed.columns.duplicated(keep=False)
        duplicate_cols = df_fixed.columns[duplicate_mask]

        # Create new column names with suffixes
        new_columns = df_fixed.columns.tolist()
        seen = {}

        for i, col in enumerate(new_columns):
            if col in duplicate_cols:
                if col not in seen:
                    seen[col] = 0
                else:
                    seen[col] += 1
                    new_columns[i] = f"{col}_{seen[col]}"

        df_fixed.columns = new_columns

    new_shape = df_fixed.shape
    print(f"Shape change: {original_shape} → {new_shape}")
    print(f"Columns removed: {original_shape[1] - new_shape[1]}")

    return df_fixed

def check_specific_date_columns(df, df_name="DataFrame"):
    """
    Specifically check start_date and end_date columns
    """
    print(f"\n DATE COLUMN ANALYSIS FOR {df_name}")
    print("-"*40)

    for col_name in ['start_date', 'end_date']:
        if col_name in df.columns:
            # Check if selecting this column returns DataFrame or Series
            selected = df[col_name]

            print(f"\n'{col_name}' column:")
            print(f"  Type when selected: {type(selected)}")

            if isinstance(selected, pd.DataFrame):
                print(f"  Returns DataFrame with shape: {selected.shape}")
                print(f"  This means there are {selected.shape[1]} columns named '{col_name}'")

                # Show sample data from each duplicate
                for i in range(selected.shape[1]):
                    sample = selected.iloc[:3, i].tolist()
                    print(f"    Column {i} sample: {sample}")

            else:  # Series
                print(f"  Returns Series with shape: {selected.shape}")
                print(f"  Data type: {selected.dtype}")
                sample = selected.head(3).tolist()
                print(f"  Sample data: {sample}")

# Usage functions
def full_diagnosis_and_fix(df, df_name="DataFrame"):
    """
    Complete diagnosis and fix for duplicate columns
    """
    print(f"COMPLETE DUPLICATE COLUMN DIAGNOSIS FOR {df_name}")
    print("="*70)

    # General duplicate check
    duplicate_cols = diagnose_duplicate_columns(df, df_name)

    # Specific date column check
    check_specific_date_columns(df, df_name)

    # Recommend fix
    if duplicate_cols:
        print(f"\n RECOMMENDED FIXES:")
        print(f"1. Keep first occurrence: df_fixed = df.loc[:, ~df.columns.duplicated()]")
        print(f"2. Keep last occurrence: df_fixed = df.loc[:, ~df.columns.duplicated(keep='last')]")
        print(f"3. Add suffixes: Use fix_duplicate_columns(df, 'suffix')")

        print(f"\n WARNING: After fixing, recheck feature columns count!")
        print(f"   Current total columns: {df.shape[1]}")
        print(f"   Unique column names: {len(df.columns.unique())}")

    return duplicate_cols

# %%
duplicate_issues = full_diagnosis_and_fix(final_df, "final_df")

if duplicate_issues:
  final_df_fixed = fix_duplicate_columns(final_df, 'keep_first')

print("\n FIX VERIFICATION:")
check_specific_date_columns(final_df_fixed, "final_df_fixed")
# Out:
# COMPLETE DUPLICATE COLUMN DIAGNOSIS FOR final_df
# ======================================================================
# DUPLICATE COLUMN ANALYSIS FOR final_df
# ============================================================
# DUPLICATE COLUMNS FOUND: 13
# Duplicate column names: ['MAL_ID', 'Name', 'Score', 'Genres', 'Episodes', 'Producers', 'Studios', 'Duration', 'Rating', 'sypnopsis', 'start_date', 'end_date', 'ongoing']
#
# Column 'start_date' appears at positions: [12, 25]
#   Data identical across duplicates: True
#   Position 12 sample: [Timestamp('1998-04-03 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-04-01 00:00:00')]
#   Position 25 sample: [Timestamp('1998-04-03 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-04-01 00:00:00')]
#
# Column 'MAL_ID' appears at positions: [0, 15]
#   Data identical across duplicates: True
#   Position 0 sample: [1, 5, 6]
#   Position 15 sample: [1, 5, 6]
#
# Column 'Score' appears at positions: [2, 17]
#   Data identical across duplicates: True
#   Position 2 sample: ['8.78', '8.39', '8.24']
#   Position 17 sample: ['8.78', '8.39', '8.24']
#
# Column 'Producers' appears at positions: [6, 20]
#   Data identical across duplicates: True
#   Position 6 sample: ['bandai visual', 'sunrise bandai visual', 'victor entertainment']
#   Position 20 sample: ['bandai visual', 'sunrise bandai visual', 'victor entertainment']
#
# Column 'Duration' appears at positions: [9, 22]
#   Data identical across duplicates: False
#   Position 9 sample: [24, 55, 24]
#   Position 22 sample: ['24 min per ep', '1 hr 55 min', '24 min per ep']
#
# Column 'Rating' appears at positions: [10, 23]
#   Data identical across duplicates: True
#   Position 10 sample: ['r - 17 violence profanity', 'r - 17 violence profanity', 'pg-13 - teens 13 or older']
#   Position 23 sample: ['r - 17 violence profanity', 'r - 17 violence profanity', 'pg-13 - teens 13 or older']
#
# Column 'sypnopsis' appears at positions: [11, 24]
#   Data identical across duplicates: True
#   Position 11 sample: ['in the year 2071 humanity has colonized several of the planets and moons of the solar system leaving the now uninhabitable surface of planet earth behind the inter solar system police attempts to keep peace in the galaxy aided in part by outlaw bounty hunters referred to as cowboys the ragtag team aboard the spaceship bebop are two such individuals mellow and carefree spike spiegel is balanced by his boisterous pragmatic partner jet black as the pair makes a living chasing bounties and collecting rewards thrown off course by the addition of new members that they meet in their travels ein a genetically engineered highly intelligent welsh corgi femme fatale faye valentine an enigmatic trickster with memory loss and the strange computer whiz kid edward wong the crew embarks on thrilling adventures that unravel each member s dark and mysterious past little by little well-balanced with high density action and light-hearted comedy cowboy bebop is a space western classic and an homage to the smooth and improvised music it is named after', 'other day another bounty such is the life of the often unlucky crew of the bebop however this routine is interrupted when faye who is chasing a fairly worthless target on mars witnesses an oil tanker suddenly explode causing mass hysteria as casualties mount due to a strange disease spreading through the smoke from the blast a whopping three hundred million woolong price is placed on the head of the supposed perpetrator with lives at stake and a solution to their money problems in sight the bebop crew springs into action spike jet faye and edward followed closely by ein split up to pursue different leads across alba city through their individual investigations they discover a cover-up scheme involving a pharmaceutical company revealing a plot that reaches much further than the ragtag team of bounty hunters could have realized', 'vash the stampede is the man with a 60 000 000 000 bounty on his head the reason he s a merciless villain who lays waste to all those that oppose him and flattens entire cities for fun garnering him the title the humanoid typhoon he leaves a trail of death and destruction wherever he goes and anyone can count themselves dead if they so much as make eye contact or so the rumors say in actuality vash is a huge softie who claims to have never taken a life and avoids violence at all costs with his crazy doughnut obsession and buffoonish attitude in tow vash traverses the wasteland of the planet gunsmoke all the while followed by two insurance agents meryl stryfe and milly thompson who attempt to minimize his impact on the public but soon their misadventures evolve into life-or-death situations as a group of legendary assassins are summoned to bring about suffering to the trio vash s agonizing past will be unraveled and his morality and principles pushed to the breaking point']
#   Position 24 sample: ['in the year 2071 humanity has colonized several of the planets and moons of the solar system leaving the now uninhabitable surface of planet earth behind the inter solar system police attempts to keep peace in the galaxy aided in part by outlaw bounty hunters referred to as cowboys the ragtag team aboard the spaceship bebop are two such individuals mellow and carefree spike spiegel is balanced by his boisterous pragmatic partner jet black as the pair makes a living chasing bounties and collecting rewards thrown off course by the addition of new members that they meet in their travels ein a genetically engineered highly intelligent welsh corgi femme fatale faye valentine an enigmatic trickster with memory loss and the strange computer whiz kid edward wong the crew embarks on thrilling adventures that unravel each member s dark and mysterious past little by little well-balanced with high density action and light-hearted comedy cowboy bebop is a space western classic and an homage to the smooth and improvised music it is named after', 'other day another bounty such is the life of the often unlucky crew of the bebop however this routine is interrupted when faye who is chasing a fairly worthless target on mars witnesses an oil tanker suddenly explode causing mass hysteria as casualties mount due to a strange disease spreading through the smoke from the blast a whopping three hundred million woolong price is placed on the head of the supposed perpetrator with lives at stake and a solution to their money problems in sight the bebop crew springs into action spike jet faye and edward followed closely by ein split up to pursue different leads across alba city through their individual investigations they discover a cover-up scheme involving a pharmaceutical company revealing a plot that reaches much further than the ragtag team of bounty hunters could have realized', 'vash the stampede is the man with a 60 000 000 000 bounty on his head the reason he s a merciless villain who lays waste to all those that oppose him and flattens entire cities for fun garnering him the title the humanoid typhoon he leaves a trail of death and destruction wherever he goes and anyone can count themselves dead if they so much as make eye contact or so the rumors say in actuality vash is a huge softie who claims to have never taken a life and avoids violence at all costs with his crazy doughnut obsession and buffoonish attitude in tow vash traverses the wasteland of the planet gunsmoke all the while followed by two insurance agents meryl stryfe and milly thompson who attempt to minimize his impact on the public but soon their misadventures evolve into life-or-death situations as a group of legendary assassins are summoned to bring about suffering to the trio vash s agonizing past will be unraveled and his morality and principles pushed to the breaking point']
#
# Column 'Genres' appears at positions: [3, 18]
#   Data identical across duplicates: True
#   Position 3 sample: ['action adventure comedy drama sci-fi space', 'action drama mystery sci-fi space', 'action sci-fi adventure comedy drama shounen']
#   Position 18 sample: ['action adventure comedy drama sci-fi space', 'action drama mystery sci-fi space', 'action sci-fi adventure comedy drama shounen']
#
# Column 'Studios' appears at positions: [7, 21]
#   Data identical across duplicates: True
#   Position 7 sample: ['sunrise', 'bones', 'madhouse']
#   Position 21 sample: ['sunrise', 'bones', 'madhouse']
#
# Column 'end_date' appears at positions: [13, 26]
#   Data identical across duplicates: True
#   Position 13 sample: [Timestamp('1999-04-24 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-09-30 00:00:00')]
#   Position 26 sample: [Timestamp('1999-04-24 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-09-30 00:00:00')]
#
# Column 'Name' appears at positions: [1, 16]
#   Data identical across duplicates: True
#   Position 1 sample: ['Cowboy Bebop', 'Cowboy Bebop: Tengoku no Tobira', 'Trigun']
#   Position 16 sample: ['Cowboy Bebop', 'Cowboy Bebop: Tengoku no Tobira', 'Trigun']
#
# Column 'Episodes' appears at positions: [5, 19]
#   Data identical across duplicates: True
#   Position 5 sample: ['26', '1', '26']
#   Position 19 sample: ['26', '1', '26']
#
# Column 'ongoing' appears at positions: [14, 27]
#   Data identical across duplicates: True
#   Position 14 sample: [False, False, False]
#   Position 27 sample: [False, False, False]
#
#  DATE COLUMN ANALYSIS FOR final_df
# ----------------------------------------
#
# 'start_date' column:
#   Type when selected: <class 'pandas.core.frame.DataFrame'>
#   Returns DataFrame with shape: (5259, 2)
#   This means there are 2 columns named 'start_date'
#     Column 0 sample: [Timestamp('1998-04-03 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-04-01 00:00:00')]
#     Column 1 sample: [Timestamp('1998-04-03 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-04-01 00:00:00')]
#
# 'end_date' column:
#   Type when selected: <class 'pandas.core.frame.DataFrame'>
#   Returns DataFrame with shape: (5259, 2)
#   This means there are 2 columns named 'end_date'
#     Column 0 sample: [Timestamp('1999-04-24 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-09-30 00:00:00')]
#     Column 1 sample: [Timestamp('1999-04-24 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-09-30 00:00:00')]
#
#  RECOMMENDED FIXES:
# 1. Keep first occurrence: df_fixed = df.loc[:, ~df.columns.duplicated()]
# 2. Keep last occurrence: df_fixed = df.loc[:, ~df.columns.duplicated(keep='last')]
# 3. Add suffixes: Use fix_duplicate_columns(df, 'suffix')
#
#  WARNING: After fixing, recheck feature columns count!
#    Current total columns: 2235
#    Unique column names: 2222
#
#  FIXING DUPLICATE COLUMNS (strategy: keep_first)
# Shape change: (5259, 2235) → (5259, 2222)
# Columns removed: 13
#
#  FIX VERIFICATION:
#
#  DATE COLUMN ANALYSIS FOR final_df_fixed
# ----------------------------------------
#
# 'start_date' column:
#   Type when selected: <class 'pandas.core.series.Series'>
#   Returns Series with shape: (5259,)
#   Data type: datetime64[ns]
#   Sample data: [Timestamp('1998-04-03 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-04-01 00:00:00')]
#
# 'end_date' column:
#   Type when selected: <class 'pandas.core.series.Series'>
#   Returns Series with shape: (5259,)
#   Data type: datetime64[ns]
#   Sample data: [Timestamp('1999-04-24 00:00:00'), Timestamp('2001-09-01 00:00:00'), Timestamp('1998-09-30 00:00:00')]

# %%
final_df_fixed
# Out:
#       MAL_ID                                               Name Score  \
# 0          1                                       Cowboy Bebop  8.78
# 1          5                    Cowboy Bebop: Tengoku no Tobira  8.39
# 2          6                                             Trigun  8.24
# 3          7                                 Witch Hunter Robin  7.27
# 4          8                                     Bouken Ou Beet  6.98
# ...      ...                                                ...   ...
# 5254   44086                                           Prayer X  6.75
# 5255   44208                                      Yami Shibai 8  6.09
# 5256   44236  Senyoku no Sigrdrifa: Dai-909 Senjutsu Hime-ta...  5.87
# 5257   46118                       Wave!!: Surfing Yappe!! (TV)  6.05
# 5258   48456                                SK∞: Crazy Rock Jam  6.52
#
#                                               Genres     Type Episodes  \
# 0         action adventure comedy drama sci-fi space       tv       26
# 1                  action drama mystery sci-fi space    movie        1
# 2       action sci-fi adventure comedy drama shounen       tv       26
# 3     action mystery police supernatural drama magic       tv       26
# 4             adventure fantasy shounen supernatural       tv       52
# ...                                              ...      ...      ...
# 5254                                  music dementia    music        1
# 5255                    dementia horror supernatural       tv       -1
# 5256                                 action military  special        1
# 5257                            slice of life sports       tv       12
# 5258                                   comedy sports  special        1
#
#                                               Producers           Studios  \
# 0                                         bandai visual           sunrise
# 1                                 sunrise bandai visual             bones
# 2                                  victor entertainment          madhouse
# 3     tv tokyo bandai visual dentsu victor entertain...           sunrise
# 4                                       tv tokyo dentsu    toei animation
# ...                                                 ...               ...
# 5254                           sony music entertainment        perimetron
# 5255                                           tv tokyo              ilca
# 5256                                            aniplex      a-1 pictures
# 5257                                        delfi sound  asahi production
# 5258                        aniplex movic abc animation             bones
#
#         Source  Duration  ...   emb_374   emb_375   emb_376   emb_377  \
# 0     original        24  ...  0.041378 -0.008807 -0.051468  0.120270
# 1     original        55  ...  0.073409 -0.031580  0.000875  0.026888
# 2        manga        24  ...  0.023642 -0.000594 -0.080299 -0.000698
# 3     original        25  ... -0.047775  0.064541  0.046725 -0.029462
# 4        manga        23  ... -0.033185 -0.002945 -0.058816  0.033064
# ...        ...       ...  ...       ...       ...       ...       ...
# 5254  original         3  ...  0.090700  0.107044  0.018753  0.032493
# 5255  original         4  ... -0.038754  0.044209 -0.009307 -0.062289
# 5256  original        24  ... -0.019292  0.031462 -0.017796  0.056616
# 5257     other        23  ...  0.011168 -0.010487 -0.063942  0.010269
# 5258  original        23  ...  0.047236  0.063548  0.056134 -0.027546
#
#        emb_378   emb_379   emb_380   emb_381   emb_382   emb_383
# 0    -0.005928 -0.009226  0.028198 -0.043460 -0.016529 -0.058174
# 1    -0.017871  0.012852  0.039618 -0.157760 -0.005686  0.008987
# 2    -0.032473 -0.009470  0.029656 -0.087012  0.050944 -0.024974
# 3    -0.025879 -0.040388  0.018040 -0.053823  0.057935 -0.021244
# 4    -0.045447  0.008317  0.054319 -0.091631  0.057574  0.011912
# ...        ...       ...       ...       ...       ...       ...
# 5254 -0.080742 -0.051087  0.026453  0.029584  0.029692 -0.042751
# 5255 -0.030723  0.008113  0.105199  0.028377 -0.034312  0.024800
# 5256 -0.062369 -0.038634  0.092818 -0.008020 -0.033852 -0.005082
# 5257 -0.042241  0.042111  0.104969  0.026636 -0.065326  0.028177
# 5258 -0.077629 -0.005455  0.038982 -0.015756 -0.089458  0.045026
#
# [5259 rows x 2222 columns]

# %%
def check_dataframe_compatibility(anime_df, final_df):
    """
    Comprehensive compatibility check for AniRecs
    """
    print(" DATAFRAME COMPATIBILITY CHECK")
    print("="*60)

    # Basic df info
    print("\n1. BASIC DATAFRAME INFORMATION:")
    print(f"anime_df shape: {anime_df.shape}")
    print(f"final_df shape: {final_df.shape}")
    print(f"Row count match: {anime_df.shape[0] == final_df.shape[0]}")

    # Check required columns
    print("\n2. REQUIRED COLUMNS CHECK:")

    # Required columns for anime_df
    anime_required_columns = [
        'MAL_ID', 'Name', 'Score', 'Genres', 'Type', 'Episodes',
        'Producers', 'Studios', 'start_date', 'end_date'
    ]

    # Required columns for final_df
    final_required_columns = [
        'MAL_ID', 'Name', 'start_date', 'end_date', 'ongoing',
        'sypnopsis', 'Genres', 'Producers', 'Studios', 'Rating', 'Type', 'Source'
    ]

    print("anime_df missing columns:")
    anime_missing = [col for col in anime_required_columns if col not in anime_df.columns]
    print(f"  {anime_missing if anime_missing else 'None - All required columns present ✓'}")

    print("final_df missing columns:")
    final_missing = [col for col in final_required_columns if col not in final_df.columns]
    print(f"  {final_missing if final_missing else 'None - All required columns present ✓'}")

    # 3. Check data types
    print("\n3. CRITICAL DATA TYPES CHECK:")

    # Check date columns - handle both DataFrame and Series
    date_columns = ['start_date', 'end_date']
    for col in date_columns:
        if col in anime_df.columns:
            try:
                dtype_info = anime_df[col].dtype
                print(f"anime_df['{col}'] dtype: {dtype_info}")
                if not pd.api.types.is_datetime64_any_dtype(anime_df[col]):
                    print(f"  ⚠️  WARNING: {col} should be datetime, currently {dtype_info}")
                    print(f"  Fix with: anime_df['{col}'] = pd.to_datetime(anime_df['{col}'], errors='coerce')")
            except AttributeError as e:
                print(f"anime_df['{col}'] - Error checking dtype: {e}")

        if col in final_df.columns:
            try:
                dtype_info = final_df[col].dtype
                print(f"final_df['{col}'] dtype: {dtype_info}")
                if not pd.api.types.is_datetime64_any_dtype(final_df[col]):
                    print(f"  WARNING: {col} should be datetime, currently {dtype_info}")
                    print(f"  Fix with: final_df['{col}'] = pd.to_datetime(final_df['{col}'], errors='coerce')")
            except AttributeError as e:
                print(f"final_df['{col}'] - Error checking dtype: {e}")

    # Check Score column
    if 'Score' in anime_df.columns:
        print(f"anime_df['Score'] dtype: {anime_df['Score'].dtype}")
        if anime_df['Score'].dtype == 'object':
            print("  ℹ️  Score is object type - system handles this with pd.to_numeric()")
            unique_scores = anime_df['Score'].unique()
            non_numeric = [s for s in unique_scores if pd.isna(pd.to_numeric(s, errors='coerce'))]
            if non_numeric:
                print(f"  Non-numeric values found: {non_numeric[:10]}...")  # Show first 10

    # 4. Check alignment of index
    print("\n4. INDEX ALIGNMENT CHECK:")
    if not anime_df.index.equals(final_df.index):
        print("  WARNING: DataFrame indices don't match!")
        print("  This could cause issues with similarity matrix alignment")
        print("  Consider: anime_df.reset_index(drop=True, inplace=True)")
        print("           final_df.reset_index(drop=True, inplace=True)")
    else:
        print("  Indices are aligned")

    # Check feature columns
    print("\n5. FEATURE COLUMNS FOR SIMILARITY MATRIX:")
    exclude_columns = ['MAL_ID', 'Name', 'start_date', 'end_date', 'ongoing',
                      'sypnopsis', 'Genres', 'Producers', 'Studios', 'Rating', 'Type', 'Source']

    feature_columns = [col for col in final_df.columns if col not in exclude_columns]
    print(f"Feature columns count: {len(feature_columns)}")
    print(f"First 10 feature columns: {feature_columns[:10]}")

    if len(feature_columns) == 0:
        print("  CRITICAL: No feature columns found for similarity computation!")
        print("  The system needs numerical features to compute similarity")

    # Check for non-numeric feature columns
    non_numeric_features = []
    for col in feature_columns:
        if not pd.api.types.is_numeric_dtype(final_df[col]):
            non_numeric_features.append((col, final_df[col].dtype))

    if non_numeric_features:
        print("  WARNING: Non-numeric feature columns found:")
        for col, dtype in non_numeric_features[:5]:  # Show first 5
            print(f"    {col}: {dtype}")
        print("  These should be converted to numeric or excluded")

    # Check for null values
    print("\n6. NULL VALUES IN CRITICAL COLUMNS:")

    critical_cols = ['Name', 'MAL_ID']
    for col in critical_cols:
        if col in anime_df.columns:
            null_count = anime_df[col].isnull().sum()
            print(f"anime_df['{col}'] nulls: {null_count}")
            if null_count > 0:
                print(f"  WARNING: {null_count} null values in critical column '{col}'")

    # Check nulls in feature columns
    if feature_columns:
        feature_nulls = final_df[feature_columns].isnull().sum().sum()
        print(f"Total nulls in feature columns: {feature_nulls}")
        print("  Note: System fills these with 0 in _fill_nan_in_features()")

    # Check string/categorical columns
    print("\n7. STRING COLUMNS PROCESSING CHECK:")
    string_cols = ['Genres', 'Producers', 'Studios']
    for col in string_cols:
        if col in anime_df.columns:
            null_count = anime_df[col].isnull().sum()
            total_count = len(anime_df)
            print(f"anime_df['{col}'] - Nulls: {null_count}/{total_count} ({null_count/total_count*100:.1f}%)")

            # Check data types in the column
            sample_values = anime_df[col].dropna().head(3).tolist()
            print(f"  Sample values: {sample_values}")

    # Summary of above + recs on next steps
    print("\n" + "="*60)
    print("8. SUMMARY AND RECOMMENDATIONS:")

    issues_found = []
    if anime_missing or final_missing:
        issues_found.append("Missing required columns")
    if not anime_df.index.equals(final_df.index):
        issues_found.append("Index alignment issues")
    if len(feature_columns) == 0:
        issues_found.append("No feature columns for similarity")
    if non_numeric_features:
        issues_found.append("Non-numeric feature columns")

    if issues_found:
        print("ISSUES FOUND:")
        for issue in issues_found:
            print(f"  - {issue}")
    else:
        print("✓ No critical issues found - DataFrames should work with the system")

    return {
        'anime_missing_cols': anime_missing,
        'final_missing_cols': final_missing,
        'feature_columns': feature_columns,
        'non_numeric_features': non_numeric_features,
        'indices_aligned': anime_df.index.equals(final_df.index),
        'issues_found': issues_found
    }

# %%
check_dataframe_compatibility(anime_df, final_df_fixed)
# Out:
#  DATAFRAME COMPATIBILITY CHECK
# ============================================================
#
# 1. BASIC DATAFRAME INFORMATION:
# anime_df shape: (5259, 15)
# final_df shape: (5259, 2222)
# Row count match: True
#
# 2. REQUIRED COLUMNS CHECK:
# anime_df missing columns:
#   None - All required columns present ✓
# final_df missing columns:
#   None - All required columns present ✓
#
# 3. CRITICAL DATA TYPES CHECK:
# anime_df['start_date'] dtype: datetime64[ns]
# final_df['start_date'] dtype: datetime64[ns]
# anime_df['end_date'] dtype: datetime64[ns]
# final_df['end_date'] dtype: datetime64[ns]
# anime_df['Score'] dtype: object
#   ℹ️  Score is object type - system handles this with pd.to_numeric()
#
# 4. INDEX ALIGNMENT CHECK:
#   Indices are aligned
#
# 5. FEATURE COLUMNS FOR SIMILARITY MATRIX:
# Feature columns count: 2210
# First 10 feature columns: ['Score', 'Episodes', 'Duration', 'Type_movie', 'Type_music', 'Type_ona', 'Type_ova', 'Type_special', 'Type_tv', 'Source_4-koma manga']
#   WARNING: Non-numeric feature columns found:
#     Score: object
#     Episodes: object
#   These should be converted to numeric or excluded
#
# 6. NULL VALUES IN CRITICAL COLUMNS:
# anime_df['Name'] nulls: 0
# anime_df['MAL_ID'] nulls: 0
# Total nulls in feature columns: 0
#   Note: System fills these with 0 in _fill_nan_in_features()
#
# 7. STRING COLUMNS PROCESSING CHECK:
# anime_df['Genres'] - Nulls: 0/5259 (0.0%)
#   Sample values: ['action adventure comedy drama sci-fi space', 'action drama mystery sci-fi space', 'action sci-fi adventure comedy drama shounen']
# anime_df['Producers'] - Nulls: 0/5259 (0.0%)
#   Sample values: ['bandai visual', 'sunrise bandai visual', 'victor entertainment']
# anime_df['Studios'] - Nulls: 0/5259 (0.0%)
#   Sample values: ['sunrise', 'bones', 'madhouse']
#
# ============================================================
# 8. SUMMARY AND RECOMMENDATIONS:
# ISSUES FOUND:
#   - Non-numeric feature columns
# {'anime_missing_cols': [],
#  'final_missing_cols': [],
#  'feature_columns': ['Score',
#   'Episodes',
#   'Duration',
#   'Type_movie',
#   'Type_music',
#   'Type_ona',
#   'Type_ova',
#   'Type_special',
#   'Type_tv',
#   'Source_4-koma manga',
#   'Source_book',
#   'Source_card game',
#   'Source_digital manga',
#   'Source_game',
#   'Source_light novel',
#   'Source_manga',
#   'Source_music',
#   'Source_novel',
#   'Source_original',
#   'Source_other',
#   'Source_picture book',
#   'Source_radio',
#   'Source_visual novel',
#   'Source_web manga',
#   'Genres_action',
#   'Genres_adventure',
#   'Genres_ai',
#   'Genres_arts',
#   'Genres_cars',
#   'Genres_comedy',
#   'Genres_dementia',
#   'Genres_demons',
#   'Genres_drama',
#   'Genres_ecchi',
#   'Genres_fantasy',
#   'Genres_fi',
#   'Genres_game',
#   'Genres_harem',
#   'Genres_hentai',
#   'Genres_historical',
#   'Genres_horror',
#   'Genres_josei',
#   'Genres_kids',
#   'Genres_life',
#   'Genres_magic',
#   'Genres_martial',
#   'Genres_mecha',
#   'Genres_military',
#   'Genres_music',
#   'Genres_mystery',
#   'Genres_of',
#   'Genres_parody',
#   'Genres_police',
#   'Genres_power',
#   'Genres_psychological',
#   'Genres_romance',
#   'Genres_samurai',
#   'Genres_school',
#   'Genres_sci',
#   'Genres_seinen',
#   'Genres_shoujo',
#   'Genres_shounen',
#   'Genres_slice',
#   'Genres_space',
#   'Genres_sports',
#   'Genres_super',
#   'Genres_supernatural',
#   'Genres_thriller',
#   'Genres_vampire',
#   'Genres_yaoi',
#   'Genres_yuri',
#   'Producers_12',
#   'Producers_1neo',
#   'Producers_1st',
#   'Producers_21',
#   'Producers_3xcube',
#   'Producers_4kids',
#   'Producers_5pb',
#   'Producers_80',
#   'Producers_81',
#   'Producers_abc',
#   'Producers_abe',
#   'Producers_abematv',
#   'Producers_ac',
#   'Producers_academy',
#   'Producers_ace',
#   'Producers_acquisitions',
#   'Producers_actas',
#   'Producers_active',
#   'Producers_ad',
#   'Producers_addiction',
#   'Producers_adk',
#   'Producers_adores',
#   'Producers_advance',
#   'Producers_advertising',
#   'Producers_aeon',
#   'Producers_ag',
#   'Producers_age',
#   'Producers_agency',
#   'Producers_agent',
#   'Producers_ai',
#   'Producers_aic',
#   'Producers_aichi',
#   'Producers_air',
#   'Producers_ajia',
#   'Producers_akabeisoft2',
#   'Producers_akatsuki',
#   'Producers_akita',
#   'Producers_alchemist',
#   'Producers_alchemy',
#   'Producers_alkline',
#   'Producers_amber',
#   'Producers_america',
#   'Producers_amg',
#   'Producers_amino',
#   'Producers_amuse',
#   'Producers_amusement',
#   'Producers_angelfish',
#   'Producers_ani',
#   'Producers_anik',
#   'Producers_anima',
#   'Producers_animac',
#   'Producers_animaruya',
#   'Producers_animate',
#   'Producers_animatic',
#   'Producers_animation',
#   'Producers_animations',
#   'Producers_animator',
#   'Producers_animatsu',
#   'Producers_animax',
#   'Producers_anime',
#   'Producers_animeigo',
#   'Producers_aniplex',
#   'Producers_ankama',
#   'Producers_annapuru',
#   'Producers_answer',
#   'Producers_antenna',
#   'Producers_aoi',
#   'Producers_aomori',
#   'Producers_aoni',
#   'Producers_apdream',
#   'Producers_apollon',
#   'Producers_aql',
#   'Producers_aqua',
#   'Producers_aquamarine',
#   'Producers_aquaplus',
#   'Producers_arcturus',
#   'Producers_areba',
#   'Producers_aris',
#   'Producers_arma',
#   'Producers_arquebuse',
#   'Producers_art',
#   'Producers_artist',
#   'Producers_artland',
#   'Producers_artmic',
#   'Producers_arts',
#   'Producers_asahi',
#   'Producers_asatsu',
#   'Producers_ascii',
#   'Producers_asgard',
#   'Producers_ashi',
#   'Producers_ashisuto',
#   'Producers_asmik',
#   'Producers_assez',
#   'Producers_association',
#   'Producers_at',
#   'Producers_atelier',
#   'Producers_atlus',
#   'Producers_aubec',
#   'Producers_audio',
#   'Producers_avenue',
#   'Producers_avex',
#   'Producers_az',
#   'Producers_aza',
#   'Producers_azmacy',
#   'Producers_azumaker',
#   'Producers_babylon',
#   'Producers_baku',
#   'Producers_ballerina',
#   'Producers_bandai',
#   'Producers_bang',
#   'Producers_bank',
#   'Producers_banpresto',
#   'Producers_baramiri',
#   'Producers_barnum',
#   'Producers_base',
#   'Producers_basic',
#   'Producers_beam',
#   'Producers_beans',
#   'Producers_bear',
#   'Producers_beat',
#   'Producers_bee',
#   'Producers_beijing',
#   'Producers_being',
#   'Producers_berich',
#   'Producers_bestack',
#   'Producers_beyond',
#   'Producers_bianca',
#   'Producers_big',
#   'Producers_bigface',
#   'Producers_biglobe',
#   'Producers_bilibili',
#   'Producers_bishop',
#   'Producers_bit',
#   'Producers_blade',
#   'Producers_blanc',
#   'Producers_block',
#   'Producers_blue',
#   'Producers_bmg',
#   'Producers_bonnou',
#   'Producers_booklive',
#   'Producers_books',
#   'Producers_bootleg',
#   'Producers_bouncy',
#   'Producers_box',
#   'Producers_boy',
#   'Producers_brands',
#   'Producers_brave',
#   'Producers_bridge',
#   'Producers_broadcasting',
#   'Producers_broccoli',
#   'Producers_bros',
#   'Producers_brothers',
#   'Producers_bs',
#   'Producers_bs11',
#   'Producers_bs2',
#   'Producers_bugyousho',
#   'Producers_bulls',
#   'Producers_bungeishunjuu',
#   'Producers_bunny',
#   'Producers_bus',
#   'Producers_bushiroad',
#   'Producers_bussan',
#   'Producers_buzz',
#   'Producers_c2c',
#   'Producers_ca',
#   'Producers_calf',
#   'Producers_cammot',
#   'Producers_canyon',
#   'Producers_capcom',
#   'Producers_capital',
#   'Producers_capsule',
#   'Producers_cartoon',
#   'Producers_casio',
#   'Producers_cat',
#   'Producers_cats',
#   'Producers_cbc',
#   'Producers_cbs',
#   'Producers_celsys',
#   'Producers_channel',
#   'Producers_chant',
#   'Producers_chara',
#   'Producers_characters',
#   'Producers_cherrylips',
#   'Producers_chiba',
#   'Producers_children',
#   'Producers_china',
#   'Producers_chippai',
#   'Producers_chrono',
#   'Producers_chugai',
#   'Producers_chugoku',
#   'Producers_chukyo',
#   'Producers_cic',
#   'Producers_circus',
#   'Producers_cloud22',
#   'Producers_club',
#   'Producers_co',
#   'Producers_coamix',
#   'Producers_cocoro',
#   'Producers_code',
#   'Producers_colopl',
#   'Producers_color',
#   'Producers_colored',
#   'Producers_columbia',
#   'Producers_com',
#   'Producers_comet',
#   'Producers_comic',
#   'Producers_comico',
#   'Producers_comics',
#   'Producers_comicsmart',
#   'Producers_comix',
#   'Producers_communication',
#   'Producers_communications',
#   'Producers_company',
#   'Producers_consortium',
#   'Producers_contents',
#   'Producers_core',
#   'Producers_corp',
#   'Producers_corporation',
#   'Producers_cosmic',
#   'Producers_cosmos',
#   'Producers_cospa',
#   'Producers_cosplay',
#   'Producers_cotton',
#   'Producers_council',
#   'Producers_cow',
#   'Producers_craft',
#   'Producers_craftar',
#   'Producers_create',
#   'Producers_creation',
#   'Producers_creations',
#   'Producers_creative',
#   'Producers_creators',
#   'Producers_creatures',
#   'Producers_crei',
#   'Producers_cromea',
#   'Producers_crunchyroll',
#   'Producers_cucuri',
#   'Producers_cultural',
#   'Producers_culture',
#   'Producers_curve',
#   'Producers_cyberagent',
#   'Producers_cyberconnect2',
#   'Producers_cyberstep',
#   'Producers_cyclone',
#   'Producers_cygames',
#   'Producers_d3',
#   'Producers_da',
#   'Producers_dai',
#   'Producers_daiei',
#   'Producers_daiichi',
#   'Producers_daiichikosho',
#   'Producers_daijobu',
#   'Producers_dandelion',
#   'Producers_darts',
#   'Producers_datam',
#   'Producers_daume',
#   'Producers_dax',
#   'Producers_dear',
#   'Producers_deen',
#   'Producers_deho',
#   'Producers_delfi',
#   'Producers_delightworks',
#   'Producers_dena',
#   'Producers_dentsu',
#   'Producers_design',
#   'Producers_diary',
#   'Producers_dic',
#   'Producers_digital',
#   'Producers_digiturbo',
#   'Producers_diomedéa',
#   'Producers_directions',
#   'Producers_discovery',
#   'Producers_disney',
#   'Producers_dive',
#   'Producers_dji',
#   'Producers_dk',
#   'Producers_dle',
#   'Producers_dmm',
#   'Producers_do',
#   'Producers_docomo',
#   'Producers_dog',
#   'Producers_doga',
#   'Producers_doll',
#   'Producers_don',
#   'Producers_donghua',
#   'Producers_dongyang',
#   'Producers_donuts',
#   'Producers_douga',
#   'Producers_dozeu',
#   'Producers_dream',
#   'Producers_drecom',
#   'Producers_duckbill',
#   'Producers_dugout',
#   'Producers_dust',
#   'Producers_dwango',
#   'Producers_dy',
#   'Producers_dynamic',
#   'Producers_dynamo',
#   'Producers_earth',
#   'Producers_east',
#   'Producers_ebook',
#   'Producers_echo',
#   'Producers_echoes',
#   'Producers_edge',
#   'Producers_egg',
#   'Producers_ei',
#   'Producers_eiga',
#   'Producers_eigakyoku',
#   'Producers_eigasha',
#   'Producers_eikyuu',
#   'Producers_eizo',
#   'Producers_electric',
#   'Producers_electromagneticwave',
#   'Producers_elements',
#   'Producers_elle',
#   'Producers_emi',
#   'Producers_emon',
#   'Producers_emotions',
#   'Producers_engine',
#   'Producers_enix',
#   'Producers_enlight',
#   'Producers_enoki',
#   'Producers_ensky',
#   'Producers_entama',
#   'Producers_enterbrain',
#   'Producers_enterprise',
#   'Producers_enterprises',
#   'Producers_entertainment',
#   'Producers_epicross',
#   'Producers_eswood',
#   'Producers_evil',
#   'Producers_exa',
#   'Producers_exit',
#   'Producers_eye',
#   'Producers_eyes',
#   'Producers_f4samurai',
#   'Producers_fabric',
#   'Producers_fabtone',
#   'Producers_factory',
#   'Producers_fairy',
#   'Producers_falcom',
#   'Producers_famima',
#   'Producers_fan',
#   'Producers_fanfan',
#   'Producers_fantasia',
#   'Producers_fanworks',
#   'Producers_fat',
#   'Producers_fbc',
#   'Producers_feng',
#   'Producers_fields',
#   'Producers_film',
#   'Producers_filmony',
#   'Producers_films',
#   'Producers_filmworks',
#   'Producers_finaud',
#   'Producers_firm',
#   'Producers_flag',
#   'Producers_flex',
#   'Producers_flying',
#   'Producers_force',
#   'Producers_forecast',
#   'Producers_four',
#   'Producers_fox',
#   'Producers_free',
#   'Producers_frencel',
#   'Producers_friend',
#   'Producers_frog',
#   'Producers_front',
#   'Producers_frontier',
#   'Producers_frontiers',
#   'Producers_fuji',
#   'Producers_fujiko',
#   'Producers_fujimi',
#   'Producers_fujio',
#   'Producers_fujipacific',
#   'Producers_fujishouji',
#   'Producers_fukuoka',
#   'Producers_fund',
#   'Producers_funimation',
#   'Producers_furyu',
#   'Producers_futabasha',
#   'Producers_future',
#   'Producers_futureworks',
#   'Producers_ga',
#   'Producers_gaga',
#   'Producers_gahousha',
#   'Producers_gainax',
#   'Producers_gakken',
#   'Producers_gakuin',
#   'Producers_gallery',
#   'Producers_gallop',
#   'Producers_gamegate',
#   'Producers_games',
#   'Producers_gansis',
#   'Producers_garage',
#   'Producers_garden',
#   'Producers_gate',
#   'Producers_gauge',
#   'Producers_gdh',
#   'Producers_gear',
#   'Producers_gen',
#   'Producers_genco',
#   'Producers_geneon',
#   'Producers_gentosha',
#   'Producers_ghibli',
#   'Producers_gigno',
#   'Producers_gimik',
#   'Producers_ginga',
#   'Producers_global',
#   'Producers_glovision',
#   'Producers_gogo',
#   'Producers_gonzo',
#   'Producers_good',
#   'Producers_goodbook',
#   'Producers_goon',
#   'Producers_gooneys',
#   'Producers_graduate',
#   'Producers_gram',
#   'Producers_grantdesign',
#   'Producers_graphics',
#   'Producers_graphinica',
#   'Producers_gree',
#   'Producers_green',
#   'Producers_greenwood',
#   'Producers_grey',
#   'Producers_grooove',
#   'Producers_group',
#   'Producers_grouper',
#   'Producers_gumi',
#   'Producers_gyao',
#   'Producers_gzbrain',
#   'Producers_hakoniwa',
#   'Producers_hakuhodo',
#   'Producers_hakusensha',
#   'Producers_hal',
#   'Producers_half',
#   'Producers_haoliners',
#   'Producers_happinet',
#   'Producers_happy',
#   'Producers_harappa',
#   'Producers_haruki',
#   'Producers_hasbro',
#   'Producers_hawkeye',
#   'Producers_hayakawa',
#   'Producers_head',
#   'Producers_heart',
#   'Producers_hearts',
#   'Producers_heewon',
#   'Producers_heiwa',
#   'Producers_hero',
#   'Producers_heroz',
#   'Producers_hexagon',
#   'Producers_hibari',
#   'Producers_high',
#   'Producers_highlights',
#   'Producers_highs',
#   'Producers_hikari',
#   'Producers_himajin',
#   'Producers_hirameki',
#   'Producers_hiroshi',
#   'Producers_hiroshima',
#   'Producers_hisashishi',
#   'Producers_hmv',
#   'Producers_hobby',
#   'Producers_hobi',
#   'Producers_hobibox',
#   'Producers_hochi',
#   'Producers_hokkaido',
#   'Producers_holders',
#   'Producers_holdings',
#   'Producers_home',
#   'Producers_hoods',
#   'Producers_horipro',
#   'Producers_hornets',
#   'Producers_hoso',
#   'Producers_hot',
#   'Producers_hotzipang',
#   'Producers_houbunsha',
#   'Producers_house',
#   'Producers_hulu',
#   'Producers_huoniao',
#   'Producers_i0',
#   'Producers_ibis',
#   'Producers_ichi',
#   'Producers_ichijinsha',
#   'Producers_idea',
#   'Producers_idol',
#   'Producers_ii',
#   'Producers_iinkai',
#   'Producers_ilca',
#   'Producers_ima',
#   'Producers_image',
#   'Producers_imagica',
#   'Producers_imagin',
#   'Producers_imagine',
#   'Producers_immg',
#   'Producers_in',
#   'Producers_inc',
#   'Producers_incs',
#   'Producers_indeprox',
#   'Producers_index',
#   'Producers_indigo',
#   'Producers_industrial',
#   'Producers_infinite',
#   'Producers_ing',
#   'Producers_initiative',
#   'Producers_innocent',
#   'Producers_insight',
#   'Producers_institute',
#   'Producers_interactive',
#   'Producers_international',
#   'Producers_investment',
#   'Producers_iqiyi',
#   'Producers_ishimori',
#   'Producers_it',
#   'Producers_iwatobi',
#   'Producers_izena',
#   'Producers_jack',
#   'Producers_jade',
#   'Producers_jam',
#   'Producers_jane',
#   'Producers_japan',
#   'Producers_japananime',
#   'Producers_jay',
#   'Producers_jidaigeki',
#   'Producers_jimusho',
#   'Producers_jinnan',
#   'Producers_jinnis',
#   'Producers_jm',
#   'Producers_jp',
#   'Producers_jr',
#   'Producers_jtb',
#   'Producers_juan',
#   'Producers_jumondo',
#   'Producers_jump',
#   'Producers_just',
#   'Producers_jy',
#   'Producers_kadokawa',
#   'Producers_kaeruotoko',
#   'Producers_kai',
#   'Producers_kaibutsu',
#   'Producers_kakao',
#   'Producers_kamikaze',
#   'Producers_kanade',
#   'Producers_kanetsu',
#   'Producers_kanon',
#   'Producers_kansai',
#   'Producers_kawade',
#   'Producers_kbs',
#   'Producers_kddi',
#   'Producers_kei',
#   'Producers_keisei',
#   'Producers_kelmadick',
#   'Producers_ken',
#   'Producers_kenji',
#   'Producers_kenmedia',
#   'Producers_khara',
#   'Producers_kick',
#   'Producers_kids',
#   'Producers_kikan',
#   'Producers_king',
#   'Producers_kino',
#   'Producers_kinoshita',
#   'Producers_kinyosha',
#   'Producers_kitty',
#   'Producers_kiyosumi',
#   'Producers_kjj',
#   'Producers_klab',
#   'Producers_klockworx',
#   'Producers_kmmj',
#   'Producers_knack',
#   'Producers_kobunsha',
#   'Producers_kodansha',
#   'Producers_koei',
#   'Producers_kojo',
#   'Producers_kokusai',
#   'Producers_konami',
#   'Producers_kotobukiya',
#   'Producers_koumuten',
#   'Producers_kss',
#   'Producers_kujou',
#   'Producers_kun',
#   'Producers_kyodo',
#   'Producers_kyokuchi',
#   'Producers_kyoraku',
#   'Producers_kyoto',
#   'Producers_kyotoma',
#   'Producers_kyuuma',
#   'Producers_lab',
#   'Producers_label',
#   'Producers_labo',
#   'Producers_lan',
#   'Producers_landq',
#   'Producers_lantis',
#   'Producers_lastrum',
#   'Producers_lawson',
#   'Producers_ldc',
#   'Producers_lead',
#   'Producers_league',
#   'Producers_legs',
#   'Producers_level',
#   'Producers_liber',
#   'Producers_libre',
#   'Producers_lidenfilms',
#   'Producers_life',
#   'Producers_lights',
#   'Producers_limited',
#   'Producers_limousine',
#   'Producers_line',
#   'Producers_link',
#   'Producers_linkedbrain',
#   'Producers_links',
#   'Producers_literature',
#   'Producers_live',
#   'Producers_liverpool',
#   'Producers_love',
#   'Producers_lucent',
#   'Producers_lucky',
#   'Producers_lune',
#   'Producers_machi',
#   'Producers_mad',
#   'Producers_madhouse',
#   'Producers_mag',
#   'Producers_magazine',
#   'Producers_mages',
#   'Producers_magic',
#   'Producers_magnet',
#   'Producers_mahjong',
#   'Producers_mainichi',
#   'Producers_maker',
#   'Producers_makura',
#   'Producers_management',
#   'Producers_marine',
#   'Producers_market',
#   'Producers_marketing',
#   'Producers_marone',
#   'Producers_marshal',
#   'Producers_marubeni',
#   'Producers_marui',
#   'Producers_marvel',
#   'Producers_marvelous',
#   'Producers_mary',
#   'Producers_marza',
#   'Producers_mattel',
#   'Producers_mausu',
#   'Producers_mazri',
#   'Producers_media',
#   'Producers_medianet',
#   'Producers_medicos',
#   'Producers_medicrie',
#   'Producers_meets',
#   'Producers_meiji',
#   'Producers_meitetsu',
#   'Producers_mellow',
#   'Producers_melonbooks',
#   'Producers_memory',
#   'Producers_meruhensha',
#   'Producers_micro',
#   'Producers_milestone',
#   'Producers_milky',
#   'Producers_mimamoru',
#   'Producers_mime',
#   'Producers_minami',
#   'Producers_mining',
#   'Producers_ministry',
#   'Producers_mir',
#   'Producers_miracle',
#   'Producers_mirai',
#   'Producers_mitsubishi',
#   'Producers_mixer',
#   'Producers_miyagi',
#   'Producers_mk',
#   'Producers_mobcast',
#   'Producers_mode',
#   'Producers_moonbell',
#   'Producers_mori',
#   'Producers_moriken',
#   'Producers_move',
#   'Producers_movic',
#   'Producers_movie',
#   'Producers_ms',
#   'Producers_musa',
#   'Producers_muse',
#   'Producers_mushi',
#   'Producers_music',
#   'Producers_mwp',
#   'Producers_mx',
#   'Producers_my',
#   'Producers_myrica',
#   'Producers_myung',
#   'Producers_möbius',
#   'Producers_nada',
#   'Producers_nagoya',
#   'Producers_namco',
#   'Producers_namisokan',
#   'Producers_namu',
#   'Producers_natural',
#   'Producers_naver',
#   'Producers_navy',
#   'Producers_naz',
#   'Producers_nbcuniversal',
#   'Producers_nec',
#   'Producers_neft',
#   'Producers_nelke',
#   'Producers_nelvana',
#   'Producers_netease',
#   'Producers_netflix',
#   'Producers_network',
#   'Producers_networks',
#   'Producers_newgin',
#   'Producers_nexon',
#   'Producers_next',
#   'Producers_nhk',
#   'Producers_nhn',
#   'Producers_niantic',
#   'Producers_nichiei',
#   'Producers_nichinare',
#   'Producers_nichion',
#   'Producers_nihikime',
#   'Producers_nihon',
#   'Producers_nikkatsu',
#   'Producers_nintendo',
#   'Producers_nippon',
#   'Producers_nishinippon',
#   'Producers_nitroplus',
#   'Producers_no',
#   'Producers_noboru',
#   'Producers_noix',
#   'Producers_nomad',
#   'Producers_north',
#   'Producers_notes',
#   'Producers_notion',
#   'Producers_nottv',
#   'Producers_nozomi',
#   'Producers_ntt',
#   'Producers_ntv',
#   'Producers_nue',
#   'Producers_nur',
#   'Producers_nutech',
#   'Producers_ob',
#   'Producers_occ',
#   'Producers_of',
#   'Producers_off',
#   'Producers_office',
#   'Producers_oh',
#   'Producers_okuroto',
#   'Producers_ole',
#   'Producers_olm',
#   'Producers_omnibus',
#   'Producers_on',
#   'Producers_one',
#   'Producers_onemusic',
#   'Producers_opera',
#   'Producers_orange',
#   'Producers_orchid',
#   'Producers_orix',
#   'Producers_osaka',
#   'Producers_ou',
#   'Producers_overlap',
#   'Producers_oz',
#   'Producers_pack',
#   'Producers_palm',
#   'Producers_pan',
#   'Producers_panasonic',
#   'Producers_paradise',
#   'Producers_parco',
#   'Producers_partners',
#   'Producers_pashmina',
#   'Producers_pastel',
#   'Producers_pastoral',
#   'Producers_pazzy',
#   'Producers_pcl',
#   'Producers_pencil',
#   'Producers_penguin',
#   'Producers_penta',
#   'Producers_perfect',
#   'Producers_perfectv',
#   'Producers_peter',
#   'Producers_ph',
#   'Producers_phoenix',
#   'Producers_pia',
#   'Producers_picante',
#   'Producers_picture',
#   'Producers_pictures',
#   'Producers_pierrot',
#   'Producers_pineapple',
#   'Producers_pink',
#   'Producers_pioneer',
#   'Producers_pixy',
#   'Producers_place',
#   'Producers_plala',
#   'Producers_planet',
#   'Producers_planning',
#   'Producers_playart',
#   'Producers_playground',
#   'Producers_plum',
#   'Producers_plus',
#   'Producers_po10tial',
#   'Producers_polygon',
#   'Producers_polygram',
#   'Producers_polystar',
#   'Producers_pony',
#   'Producers_ppp',
#   'Producers_pra',
#   'Producers_primastea',
#   'Producers_primetime',
#   'Producers_printing',
#   'Producers_pro',
#   'Producers_produce',
#   'Producers_producing',
#   'Producers_product',
#   'Producers_production',
#   'Producers_productions',
#   'Producers_products',
#   'Producers_project',
#   'Producers_promotion',
#   'Producers_public',
#   'Producers_publishers',
#   'Producers_publishing',
#   'Producers_purple',
#   'Producers_qreazy',
#   'Producers_quaras',
#   'Producers_quatre',
#   'Producers_queen',
#   'Producers_quick',
#   'Producers_rab',
#   'Producers_radio',
#   'Producers_radix',
#   'Producers_railway',
#   'Producers_raku',
#   'Producers_rakuonsha',
#   'Producers_rakuten',
#   'Producers_ray',
#   'Producers_razorfish',
#   'Producers_rcc',
#   'Producers_recording',
#   'Producers_records',
#   'Producers_recreation',
#   'Producers_reed',
#   'Producers_remic',
#   'Producers_rex',
#   'Producers_rialto',
#   'Producers_right',
#   'Producers_rights',
#   'Producers_righttracks',
#   'Producers_rikuentai',
#   'Producers_rings',
#   'Producers_rironsha',
#   'Producers_rme',
#   'Producers_robe',
#   'Producers_robo',
#   'Producers_robot',
#   'Producers_romantica',
#   'Producers_rondo',
#   'Producers_room',
#   'Producers_royal',
#   'Producers_run',
#   'Producers_ryukyu',
#   'Producers_saban',
#   'Producers_saitama',
#   'Producers_saki',
#   'Producers_sakura',
#   'Producers_sammy',
#   'Producers_samsung',
#   'Producers_samurai',
#   'Producers_san',
#   'Producers_sanctuary',
#   'Producers_sankyo',
#   'Producers_sanrio',
#   'Producers_sanyo',
#   'Producers_sanzigen',
#   'Producers_sapporo',
#   'Producers_saru',
#   'Producers_satelight',
#   'Producers_sav',
#   'Producers_sb',
#   'Producers_sc',
#   'Producers_school',
#   'Producers_science',
#   'Producers_sedic',
#   'Producers_seed',
#   'Producers_sega',
#   'Producers_seika',
#   'Producers_seikaisha',
#   'Producers_seisaku',
#   'Producers_sentai',
#   'Producers_setouchi',
#   'Producers_seven',
#   'Producers_shaft',
#   'Producers_shamrock',
#   'Producers_shanghai',
#   'Producers_shelty',
#   'Producers_shift',
#   'Producers_shimbun',
#   'Producers_shimogumi',
#   'Producers_shin',
#   'Producers_shinchosha',
#   'Producers_shinsha',
#   'Producers_shinshokan',
#   'Producers_shirogumi',
#   'Producers_shizuoka',
#   'Producers_shobo',
#   'Producers_shobou',
#   'Producers_shochiku',
#   'Producers_shogakukan',
#   'Producers_shokai',
#   'Producers_shoten',
#   'Producers_shounen',
#   'Producers_show',
#   'Producers_showgate',
#   'Producers_shueisha',
#   'Producers_shufunotomo',
#   'Producers_shun',
#   'Producers_shuuji',
#   'Producers_side',
#   'Producers_silky',
#   'Producers_silver',
#   'Producers_sketch',
#   'Producers_sky',
#   'Producers_sleeve',
#   'Producers_slow',
#   'Producers_sme',
#   'Producers_smile',
#   'Producers_smiral',
#   'Producers_soeishinsha',
#   'Producers_soft',
#   'Producers_softbank',
#   'Producers_software',
#   'Producers_softx',
#   ...],
#  'non_numeric_features': [('Score', dtype('O')), ('Episodes', dtype('O'))],
#  'indices_aligned': True,
#  'issues_found': ['Non-numeric feature columns']}

# %%
# Convert non-numeric feature columns to numeric
final_df_fixed['Score'] = pd.to_numeric(final_df_fixed['Score'], errors='coerce')
final_df_fixed['Episodes'] = pd.to_numeric(final_df_fixed['Episodes'], errors='coerce')

# Fill any resulting NaN values with 0
final_df_fixed['Score'] = final_df_fixed['Score'].fillna(0)
final_df_fixed['Episodes'] = final_df_fixed['Episodes'].fillna(0)
# Out:
# /tmp/ipython-input-1520754976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df_fixed['Score'] = pd.to_numeric(final_df_fixed['Score'], errors='coerce')
# /tmp/ipython-input-1520754976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df_fixed['Episodes'] = pd.to_numeric(final_df_fixed['Episodes'], errors='coerce')
# /tmp/ipython-input-1520754976.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df_fixed['Score'] = final_df_fixed['Score'].fillna(0)
# /tmp/ipython-input-1520754976.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df_fixed['Episodes'] = final_df_fixed['Episodes'].fillna(0)

# %%
final_df_fixed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5259 entries, 0 to 5258
# Columns: 2222 entries, MAL_ID to emb_383
# dtypes: bool(1), datetime64[ns](2), float32(384), float64(1824), int64(3), object(8)
# memory usage: 81.4+ MB

# %%
class AniRecs:
    def __init__(self, anime_df, final_df):
        self.anime_df = anime_df
        self.final_df = final_df
        self.feature_columns = None
        self.similarity_matrix = None
        self._prepare_features()
        self._fill_nan_in_features() # Added a step to fill NaN values
        self._compute_similarity_matrix()
        self._prepare_lookup_sets()

    def _prepare_features(self):
        """Prepare feature columns for similarity computation"""
        exclude_columns = ['MAL_ID', 'Name', 'start_date', 'end_date', 'ongoing',
                          'sypnopsis', 'Genres', 'Producers', 'Studios', 'Rating', 'Type', 'Source']

        self.feature_columns = [col for col in self.final_df.columns if col not in exclude_columns]

    def _fill_nan_in_features(self):
        """Fill NaN values in feature columns with 0"""
        self.final_df[self.feature_columns] = self.final_df[self.feature_columns].fillna(0)


    def _compute_similarity_matrix(self):
        """Compute cosine similarity matrix for all anime"""
        feature_matrix = self.final_df[self.feature_columns].values
        # feature_matrix = np.nan_to_num(feature_matrix) # This is no longer needed as NaNs are filled
        self.similarity_matrix = cosine_similarity(feature_matrix)

    def _prepare_lookup_sets(self):
        """Prepare lookup sets for genres, producers, studios"""
        self.genres_set = set()
        self.producers_set = set()
        self.studios_set = set()

        for _, row in self.anime_df.iterrows():
            if pd.notna(row['Genres']):
                self.genres_set.update([g.strip().lower() for g in str(row['Genres']).split()])
            if pd.notna(row['Producers']):
                self.producers_set.update([p.strip().lower() for p in str(row['Producers']).split()])
            if pd.notna(row['Studios']):
                self.studios_set.update([s.strip().lower() for s in str(row['Studios']).split()])

    def extract_year_decade(self, query):
        """Extract year or decade information from query"""
        query_lower = query.lower()

        # Patterns for decades with descriptors
        decade_patterns = [
            (r'\b(?:early|beginning of|start of)\s+(\d{4})s?\b', 'early'),
            (r'\b(?:mid|middle of)\s+(\d{4})s?\b', 'mid'),
            (r'\b(?:late|end of)\s+(\d{4})s?\b', 'late'),
            (r'\b(\d{4})s?\b', 'full'),  # Just the decade
            (r'\b(\d{4})\b', 'year'),     # Specific year
        ]

        # Special decade mappings
        decade_words = {
            'eighties': '1980', 'nineties': '1990', 'ninties': '1990',
            '80s': '1980', '90s': '1990', '2000s': '2000', '2010s': '2010'
        }

        # Check for word-based decades first
        for word, decade in decade_words.items():
            if word in query_lower:
                return self._get_decade_range(decade, 'full')

        # Check for numeric patterns
        for pattern, period_type in decade_patterns:
            match = re.search(pattern, query_lower)
            if match:
                year = match.group(1)
                if period_type == 'year':
                    return int(year), int(year)
                else:
                    return self._get_decade_range(year, period_type)

        return None, None

    def _get_decade_range(self, decade_start, period_type):
        """Get year range for decade periods"""
        start_year = int(decade_start)

        if period_type == 'early':
            return start_year, start_year + 3
        elif period_type == 'mid':
            return start_year + 3, start_year + 6
        elif period_type == 'late':
            return start_year + 7, start_year + 9
        else:  # full decade
            return start_year, start_year + 9

    def extract_genres(self, query):
        """Extract genres from query using fuzzy matching"""
        query_lower = query.lower()
        found_genres = []

        # Direct genre matching
        for genre in self.genres_set:
            if genre in query_lower:
                found_genres.append(genre)

        genre_synonyms = {
            'action': ['action'],
            'adventure': ['adventure'],
            'ai': ['ai'],
            'arts': ['arts'],
            'cars': ['cars'],
            'comedy': ['comedy'],
            'dementia': ['dementia'],
            'demons': ['demons'],
            'drama': ['drama'],
            'ecchi': ['ecchi'],
            'fantasy': ['fantasy', 'magic'],
            'game': ['game'],
            'harem': ['harem'],
            'hentai': ['hentai'],
            'historical': ['historical'],
            'horror': ['horror'],
            'josei': ['josei'],
            'kids': ['kids'],
            'slice of life': ['slice', 'life'],
            'martial arts': ['martial', 'arts'],
            'mecha': ['mecha'],
            'military': ['military'],
            'music': ['music'],
            'mystery': ['mystery'],
            'parody': ['parody'],
            'police': ['police'],
            'power': ['power'],
            'psychological': ['psychological'],
            'romance': ['romance'],
            'samurai': ['samurai'],
            'school': ['school'],
            'sci-fi': ['sci-fi'],
            'seinen': ['seinen'],
            'shoujo': ['shoujo'],
            'shounen': ['shounen'],
            'space': ['space'],
            'sports': ['sports'],
            'super power': ['super', 'power'],
            'supernatural': ['supernatural'],
            'thriller': ['thriller'],
            'vampire': ['vampire'],
            'yaoi': ['yaoi'],
            'yuri': ['yuri']
        }


        for genre, synonyms in genre_synonyms.items():
            for synonym in synonyms:
                if synonym in query_lower and genre not in found_genres:
                    found_genres.append(genre)
                    break

        return found_genres

    def extract_anime_name(self, query):
        """Extract anime name from similarity queries"""
        similarity_patterns = [
            r'similar to (.+?)(?:\?|$|,)',
            r'like (.+?)(?:\?|$|,)',
            r'recommend.*?(?:similar to|like) (.+?)(?:\?|$|,)',
            r'find.*?(?:similar to|like) (.+?)(?:\?|$|,)',
            r'show.*?(?:similar to|like) (.+?)(?:\?|$|,)',
        ]

        query_lower = query.lower()
        for pattern in similarity_patterns:
            match = re.search(pattern, query_lower)
            if match:
                return match.group(1).strip()

        return None

    def filter_by_time_period(self, df, start_year, end_year):
        """Filter anime by time period"""
        if start_year is None or end_year is None:
            return df

        # Filter based on start_date year
        filtered_df = df[
            (df['start_date'].dt.year >= start_year) &
            (df['start_date'].dt.year <= end_year)
        ].copy()

        return filtered_df

    def filter_by_genres(self, df, genres):
        """Filter anime by genres"""
        if not genres:
            return df

        mask = pd.Series([False] * len(df))

        for genre in genres:
            genre_mask = df['Genres'].str.contains(genre, case=False, na=False)
            mask = mask | genre_mask

        return df[mask].copy()

    def find_anime_by_name(self, query_name, threshold=0.8):
        """Find anime by name using fuzzy matching"""
        anime_names = self.anime_df['Name'].tolist()

        # Try exact match first (case insensitive)
        exact_matches = self.anime_df[self.anime_df['Name'].str.lower() == query_name.lower()]
        if not exact_matches.empty:
            return exact_matches.iloc[0]

        # Use fuzzy matching
        close_matches = get_close_matches(query_name, anime_names, n=5, cutoff=0.6)

        if close_matches:
            print(f"Found similar anime names: {close_matches}")
            best_match = close_matches[0]
            return self.anime_df[self.anime_df['Name'] == best_match].iloc[0]

        return None

    def get_similar_anime(self, anime_name, top_k=10):
        """Get similar anime recommendations based on anime name"""
        target_anime = self.find_anime_by_name(anime_name)

        if target_anime is None:
            return f"Sorry, I couldn't find an anime named '{anime_name}'. Please check the spelling or try a different name."

        target_idx = target_anime.name
        similarity_scores = self.similarity_matrix[target_idx]
        similar_indices = np.argsort(similarity_scores)[::-1][1:top_k+1]

        recommendations = []
        for idx in similar_indices:
            anime_info = self.anime_df.iloc[idx]
            recommendations.append({
                'name': anime_info['Name'],
                'score': anime_info['Score'],
                'genres': anime_info['Genres'],
                'type': anime_info['Type'],
                'episodes': anime_info['Episodes'],
                'similarity_score': similarity_scores[idx],
                'mal_id': anime_info['MAL_ID'],
                'start_year': anime_info['start_date'].year if pd.notna(anime_info['start_date']) else 'Unknown'
            })

        return recommendations

    def get_filtered_recommendations(self, start_year=None, end_year=None, genres=None, top_k=10, min_score=6.0):
        """Get recommendations based on filters"""
        # Start with full dataset
        filtered_df = self.anime_df.copy()

        # Apply time filter
        if start_year is not None and end_year is not None:
            filtered_df = self.filter_by_time_period(filtered_df, start_year, end_year)

        # Apply genre filter
        if genres:
            filtered_df = self.filter_by_genres(filtered_df, genres)

        # Filter by minimum score and remove entries with unknown scores
        filtered_df = filtered_df[
            (pd.to_numeric(filtered_df['Score'], errors='coerce') >= min_score) &
            (filtered_df['Score'] != 'Unknown')
        ]

        if filtered_df.empty:
            return "No anime found matching your criteria. Try adjusting your filters."

        # Sort by score and return top results
        filtered_df = filtered_df.sort_values('Score', ascending=False).head(top_k)

        recommendations = []
        for _, anime_info in filtered_df.iterrows():
            recommendations.append({
                'name': anime_info['Name'],
                'score': anime_info['Score'],
                'genres': anime_info['Genres'],
                'type': anime_info['Type'],
                'episodes': anime_info['Episodes'],
                'mal_id': anime_info['MAL_ID'],
                'start_year': anime_info['start_date'].year if pd.notna(anime_info['start_date']) else 'Unknown'
            })

        return recommendations

    def process_user_query(self, user_input, top_k=10):
        """Process various types of natural language queries"""
        user_input_lower = user_input.lower().strip()

        # Check if it's a similarity-based query
        anime_name = self.extract_anime_name(user_input)
        if anime_name:
            return self.get_similar_anime(anime_name, top_k)

        # Extract time period
        start_year, end_year = self.extract_year_decade(user_input)

        # Extract genres
        genres = self.extract_genres(user_input)

        # If we have filters, use filtered recommendations
        if start_year or genres:
            return self.get_filtered_recommendations(
                start_year=start_year,
                end_year=end_year,
                genres=genres,
                top_k=top_k
            )

        # If no specific filters, try to find the most relevant recommendation type
        if any(word in user_input_lower for word in ['good', 'recommend', 'suggest', 'show']):
            # General recommendation - return top rated anime
            return self.get_filtered_recommendations(top_k=top_k, min_score=7.0)

        return "I couldn't understand your request. Please try queries like:\n" + \
               "- 'recommend anime similar to One Piece'\n" + \
               "- 'what are some good animes from the 90s'\n" + \
               "- 'recommend me some action animes from the early 2000s'\n" + \
               "- 'please recommend me some sci-fi animes'"

    def display_recommendations(self, recommendations, query_info=None):
        """Display recommendations in a nice format"""
        if isinstance(recommendations, str):
            print(recommendations)
            return

        if query_info:
            print(f"\n🎌 {query_info}:\n")
        else:
            print("\n🎌 Recommended Anime:\n")

        for i, anime in enumerate(recommendations, 1):
            print(f"{i}. {anime['name']}")
            print(f"   📊 Score: {anime['score']} | 📺 Type: {anime['type']} | 📋 Episodes: {anime['episodes']}")
            print(f"   🎭 Genres: {anime['genres']}")

            if 'similarity_score' in anime:
                print(f"   🔗 Similarity: {anime['similarity_score']:.3f}")

            if 'start_year' in anime:
                print(f"   📅 Year: {anime['start_year']}")

            print(f"   🆔 MAL ID: {anime['mal_id']}")
            print("-" * 60)

def create_recommendation_system(anime_df, final_df):
    """Create and return the recommendation system"""
    return AniRecs(anime_df, final_df)

def demonstrate_system(anime_df, final_df):
    """Demonstrate the  recommendation system"""
    recommender = create_recommendation_system(anime_df, final_df)

    # Test queries
    test_queries = [
        "what are some good animes from the 90s",
        "recommend me some action animes from the early 2000s",
        "recommend me some slice of life animes from the late 2010s",
        "please recommend me an anime similar to one piece",
        "please recommend me some adventure animes",
        "please recommend me some sci-fi animes"
    ]

    for query in test_queries:
        print(f"\n{'='*80}")
        print(f"User Query: '{query}'")
        print('='*80)

        recommendations = recommender.process_user_query(query, top_k=5)
        recommender.display_recommendations(recommendations)

def interactive_system(anime_df, final_df):
    """Interactive recommendation system"""
    recommender = create_recommendation_system(anime_df, final_df)

    print("🎌 Welcome to AniRecs!")
    print("\nSupported query types:")
    print("📅 Time-based: 'what are some good animes from the 90s'")
    print("🎭 Genre-based: 'recommend me some action animes'")
    print("📅🎭 Combined: 'recommend me some sci-fi animes from the early 2000s'")
    print("🔗 Similarity: 'recommend anime similar to One Piece'")
    print("\nType 'quit' to exit\n")

    while True:
        user_input = input("What would you like? ").strip()

        if user_input.lower() in ['quit', 'exit', 'q']:
            print("Thanks for using AniRecs!")
            break

        if not user_input:
            print("Please enter a query.")
            continue

        recommendations = recommender.process_user_query(user_input)
        recommender.display_recommendations(recommendations)
        print()

# %%
# Initialize the recommendation system
print("🔧 Initializing AniRecs...")
recommender = create_recommendation_system(anime_df, final_df_fixed)
print("✅ System initialized successfully!\n")

# Test different query types
queries = [
    "what are some good animes from the 90s",
    "recommend me some action animes from the early 2000s",
    "recommend me some slice of life animes from the late 2010s",
    "please recommend me an anime similar to one piece",
    "please recommend me some adventure animes",
    "please recommend me some sci-fi animes"
]

print("🧪 Testing different query types:\n")

for i, query in enumerate(queries, 1):
    print(f"\n{'='*80}")
    print(f"TEST {i}: '{query}'")
    print('='*80)

    try:
        recommendations = recommender.process_user_query(query, top_k=5)
        recommender.display_recommendations(recommendations)
    except Exception as e:
        print(f"❌ Error processing query: {e}")

print("\n🎉 All tests completed!")
# Out:
# 🔧 Initializing AniRecs...
# /tmp/ipython-input-2531193042.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.final_df[self.feature_columns] = self.final_df[self.feature_columns].fillna(0)
# ✅ System initialized successfully!
#
# 🧪 Testing different query types:
#
#
# ================================================================================
# TEST 1: 'what are some good animes from the 90s'
# ================================================================================
#
# 🎌 Recommended Anime:
#
# 1. Cowboy Bebop
#    📊 Score: 8.78 | 📺 Type: tv | 📋 Episodes: 26
#    🎭 Genres: action adventure comedy drama sci-fi space
#    📅 Year: 1998
#    🆔 MAL ID: 1
# ------------------------------------------------------------
# 2. Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen
#    📊 Score: 8.73 | 📺 Type: ova | 📋 Episodes: 4
#    🎭 Genres: action historical drama romance martial arts samurai shounen
#    📅 Year: 1999
#    🆔 MAL ID: 44
# ------------------------------------------------------------
# 3. Mononoke Hime
#    📊 Score: 8.72 | 📺 Type: movie | 📋 Episodes: 1
#    🎭 Genres: action adventure fantasy
#    📅 Year: 1997
#    🆔 MAL ID: 164
# ------------------------------------------------------------
# 4. Great Teacher Onizuka
#    📊 Score: 8.7 | 📺 Type: tv | 📋 Episodes: 43
#    🎭 Genres: slice of life comedy drama school shounen
#    📅 Year: 1999
#    🆔 MAL ID: 245
# ------------------------------------------------------------
# 5. Slam Dunk
#    📊 Score: 8.53 | 📺 Type: tv | 📋 Episodes: 101
#    🎭 Genres: comedy drama school shounen sports
#    📅 Year: 1993
#    🆔 MAL ID: 170
# ------------------------------------------------------------
#
# ================================================================================
# TEST 2: 'recommend me some action animes from the early 2000s'
# ================================================================================
#
# 🎌 Recommended Anime:
#
# 1. Gintama
#    📊 Score: 8.96 | 📺 Type: tv | 📋 Episodes: 201
#    🎭 Genres: action comedy historical parody samurai sci-fi shounen
#    📅 Year: 2006
#    🆔 MAL ID: 918
# ------------------------------------------------------------
# 2. Code Geass: Hangyaku no Lelouch
#    📊 Score: 8.72 | 📺 Type: tv | 📋 Episodes: 25
#    🎭 Genres: action military sci-fi super power drama mecha school
#    📅 Year: 2006
#    🆔 MAL ID: 1575
# ------------------------------------------------------------
# 3. Tengen Toppa Gurren Lagann
#    📊 Score: 8.66 | 📺 Type: tv | 📋 Episodes: 27
#    🎭 Genres: action adventure comedy mecha sci-fi
#    📅 Year: 2007
#    🆔 MAL ID: 2001
# ------------------------------------------------------------
# 4. Koukaku Kidoutai: Stand Alone Complex 2nd GIG
#    📊 Score: 8.54 | 📺 Type: tv | 📋 Episodes: 26
#    🎭 Genres: action military sci-fi mystery police mecha seinen
#    📅 Year: 2004
#    🆔 MAL ID: 801
# ------------------------------------------------------------
# 5. Samurai Champloo
#    📊 Score: 8.5 | 📺 Type: tv | 📋 Episodes: 26
#    🎭 Genres: action adventure comedy historical samurai shounen
#    📅 Year: 2004
#    🆔 MAL ID: 205
# ------------------------------------------------------------
#
# ================================================================================
# TEST 3: 'recommend me some slice of life animes from the late 2010s'
# ================================================================================
#
# 🎌 Recommended Anime:
#
# 1. 3-gatsu no Lion 2nd Season
#    📊 Score: 9.0 | 📺 Type: tv | 📋 Episodes: 22
#    🎭 Genres: drama game seinen slice of life
#    📅 Year: 2017
#    🆔 MAL ID: 35180
# ------------------------------------------------------------
# 2. Mob Psycho 100 II
#    📊 Score: 8.84 | 📺 Type: tv | 📋 Episodes: 13
#    🎭 Genres: action slice of life comedy supernatural
#    📅 Year: 2019
#    🆔 MAL ID: 37510
# ------------------------------------------------------------
# 3. Mushishi Zoku Shou 2nd Season
#    📊 Score: 8.76 | 📺 Type: tv | 📋 Episodes: 10
#    🎭 Genres: adventure fantasy historical mystery seinen slice of life supernatural
#    📅 Year: 2014
#    🆔 MAL ID: 24701
# ------------------------------------------------------------
# 4. Mushishi Zoku Shou
#    📊 Score: 8.72 | 📺 Type: tv | 📋 Episodes: 10
#    🎭 Genres: adventure slice of life mystery historical supernatural fantasy seinen
#    📅 Year: 2014
#    🆔 MAL ID: 21939
# ------------------------------------------------------------
# 5. Natsume Yuujinchou Shi
#    📊 Score: 8.67 | 📺 Type: tv | 📋 Episodes: 13
#    🎭 Genres: slice of life demons supernatural drama shoujo
#    📅 Year: 2012
#    🆔 MAL ID: 11665
# ------------------------------------------------------------
#
# ================================================================================
# TEST 4: 'please recommend me an anime similar to one piece'
# ================================================================================
#
# 🎌 Recommended Anime:
#
# 1. Dragon Quest: Dai no Daibouken (2020)
#    📊 Score: 7.08 | 📺 Type: tv | 📋 Episodes: -1
#    🎭 Genres: action adventure fantasy shounen
#    🔗 Similarity: 0.996
#    📅 Year: 2020
#    🆔 MAL ID: 40906
# ------------------------------------------------------------
# 2. Detective Conan
#    📊 Score: 8.16 | 📺 Type: tv | 📋 Episodes: -1
#    🎭 Genres: adventure mystery comedy police shounen
#    🔗 Similarity: 0.995
#    📅 Year: 1996
#    🆔 MAL ID: 235
# ------------------------------------------------------------
# 3. Kingdom 3rd Season
#    📊 Score: 8.4 | 📺 Type: tv | 📋 Episodes: -1
#    🎭 Genres: action historical military seinen
#    🔗 Similarity: 0.993
#    📅 Year: 2020
#    🆔 MAL ID: 40682
# ------------------------------------------------------------
# 4. Doraemon (2005)
#    📊 Score: 7.52 | 📺 Type: tv | 📋 Episodes: -1
#    🎭 Genres: sci-fi comedy kids shounen
#    🔗 Similarity: 0.993
#    📅 Year: 2005
#    🆔 MAL ID: 8687
# ------------------------------------------------------------
# 5. Beastars 2nd Season
#    📊 Score: 8.06 | 📺 Type: tv | 📋 Episodes: -1
#    🎭 Genres: slice of life psychological drama shounen
#    🔗 Similarity: 0.993
#    📅 Year: 2021
#    🆔 MAL ID: 40935
# ------------------------------------------------------------
#
# ================================================================================
# TEST 5: 'please recommend me some adventure animes'
# ================================================================================
#
# 🎌 Recommended Anime:
#
# 1. Fullmetal Alchemist: Brotherhood
#    📊 Score: 9.19 | 📺 Type: tv | 📋 Episodes: 64
#    🎭 Genres: action military adventure comedy drama magic fantasy shounen
#    📅 Year: 2009
#    🆔 MAL ID: 5114
# ------------------------------------------------------------
# 2. Hunter x Hunter (2011)
#    📊 Score: 9.1 | 📺 Type: tv | 📋 Episodes: 148
#    🎭 Genres: action adventure fantasy shounen super power
#    📅 Year: 2011
#    🆔 MAL ID: 11061
# ------------------------------------------------------------
# 3. Sen to Chihiro no Kamikakushi
#    📊 Score: 8.83 | 📺 Type: movie | 📋 Episodes: 1
#    🎭 Genres: adventure supernatural drama
#    📅 Year: 2001
#    🆔 MAL ID: 199
# ------------------------------------------------------------
# 4. Cowboy Bebop
#    📊 Score: 8.78 | 📺 Type: tv | 📋 Episodes: 26
#    🎭 Genres: action adventure comedy drama sci-fi space
#    📅 Year: 1998
#    🆔 MAL ID: 1
# ------------------------------------------------------------
# 5. Mushishi Zoku Shou 2nd Season
#    📊 Score: 8.76 | 📺 Type: tv | 📋 Episodes: 10
#    🎭 Genres: adventure fantasy historical mystery seinen slice of life supernatural
#    📅 Year: 2014
#    🆔 MAL ID: 24701
# ------------------------------------------------------------
#
# ================================================================================
# TEST 6: 'please recommend me some sci-fi animes'
# ================================================================================
#
# 🎌 Recommended Anime:
#
# 1. Steins;Gate
#    📊 Score: 9.11 | 📺 Type: tv | 📋 Episodes: 24
#    🎭 Genres: thriller sci-fi
#    📅 Year: 2011
#    🆔 MAL ID: 9253
# ------------------------------------------------------------
# 2. Gintama°
#    📊 Score: 9.1 | 📺 Type: tv | 📋 Episodes: 51
#    🎭 Genres: action comedy historical parody samurai sci-fi shounen
#    📅 Year: 2015
#    🆔 MAL ID: 28977
# ------------------------------------------------------------
# 3. Gintama'
#    📊 Score: 9.08 | 📺 Type: tv | 📋 Episodes: 51
#    🎭 Genres: action sci-fi comedy historical parody samurai shounen
#    📅 Year: 2011
#    🆔 MAL ID: 9969
# ------------------------------------------------------------
# 4. Ginga Eiyuu Densetsu
#    📊 Score: 9.07 | 📺 Type: ova | 📋 Episodes: 110
#    🎭 Genres: military sci-fi space drama
#    📅 Year: 1988
#    🆔 MAL ID: 820
# ------------------------------------------------------------
# 5. Gintama': Enchousen
#    📊 Score: 9.04 | 📺 Type: tv | 📋 Episodes: 13
#    🎭 Genres: action comedy historical parody samurai sci-fi shounen
#    📅 Year: 2012
#    🆔 MAL ID: 15417
# ------------------------------------------------------------
#
# 🎉 All tests completed!
# /tmp/ipython-input-2531193042.py:200: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return df[mask].copy()
# /tmp/ipython-input-2531193042.py:200: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return df[mask].copy()
